# %% [markdown]
# ## Kaggle – DataTops®
# Luismi ha decidido cambiar de aires y, por eso, ha comprado una tienda de portátiles. Sin embargo, su única especialidad es Data Science, por lo que ha decidido crear un modelo de ML para establecer los mejores precios.
#
# ¿Podrías ayudar a Luismi a mejorar ese modelo?

# %% [markdown]
# ## Métrica:
# Error de raíz cuadrada media (RMSE) es la desviación estándar de los valores residuales (errores de predicción). Los valores residuales son una medida de la distancia de los puntos de datos de la línea de regresión; RMSE es una medida de cuál es el nivel de dispersión de estos valores residuales. En otras palabras, le indica el nivel de concentración de los datos en la línea de mejor ajuste.
#
#
# $$ RMSE = \sqrt{\frac{1}{n}\Sigma_{i=1}^{n}{\Big(\frac{d_i -f_i}{\sigma_i}\Big)^2}}$$

# %% [markdown]
# ## Librerías

# %%
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import urllib.request

# %% [markdown]
# ## Datos

# %%
# Para que funcione necesitas bajarte los archivos de datos de Kaggle 
df = pd.read_csv("./data/train.csv",index_col=0)
df.index.name=None

# %% [markdown]
# ## Exploración de los datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    object
#  1   Product           912 non-null    object
#  2   TypeName          912 non-null    object
#  3   Inches            912 non-null    float64
#  4   ScreenResolution  912 non-null    object
#  5   Cpu               912 non-null    object
#  6   Ram               912 non-null    object
#  7   Memory            912 non-null    object
#  8   Gpu               912 non-null    object
#  9   OpSys             912 non-null    object
#  10  Weight            912 non-null    object
#  11  Price_in_euros    912 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 92.6+ KB

# %%
df.head()
# Out:
#     Company        Product   TypeName  Inches   ScreenResolution  \
# 755      HP         250 G6   Notebook    15.6  Full HD 1920x1080
# 618    Dell  Inspiron 7559     Gaming    15.6  Full HD 1920x1080
# 909      HP    ProBook 450   Notebook    15.6  Full HD 1920x1080
# 2     Apple    Macbook Air  Ultrabook    13.3           1440x900
# 286    Dell  Inspiron 3567   Notebook    15.6  Full HD 1920x1080
#
#                              Cpu   Ram               Memory  \
# 755     Intel Core i3 6006U 2GHz   8GB            256GB SSD
# 618  Intel Core i7 6700HQ 2.6GHz  16GB              1TB HDD
# 909   Intel Core i7 7500U 2.7GHz   8GB              1TB HDD
# 2           Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 286   Intel Core i3 6006U 2.0GHz   4GB              1TB HDD
#
#                                 Gpu       OpSys  Weight  Price_in_euros
# 755           Intel HD Graphics 520  Windows 10  1.86kg          539.00
# 618  Nvidia GeForce GTX 960<U+039C>  Windows 10  2.59kg          879.01
# 909            Nvidia GeForce 930MX  Windows 10  2.04kg          900.00
# 2            Intel HD Graphics 6000       macOS  1.34kg          898.94
# 286              AMD Radeon R5 M430       Linux  2.25kg          428.00

# %%
df.tail()
# Out:
#      Company             Product            TypeName  Inches  \
# 28      Dell       Inspiron 5570            Notebook    15.6
# 1160      HP         Spectre Pro  2 in 1 Convertible    13.3
# 78    Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 23        HP              255 G6            Notebook    15.6
# 229     Dell        Alienware 17              Gaming    17.3
#
#                      ScreenResolution                           Cpu   Ram  \
# 28                  Full HD 1920x1080    Intel Core i5 8250U 1.6GHz   8GB
# 1160  Full HD / Touchscreen 1920x1080    Intel Core i5 6300U 2.4GHz   8GB
# 78                  Full HD 1920x1080    Intel Core i5 7200U 2.5GHz   8GB
# 23                           1366x768  AMD E-Series E2-9000e 1.5GHz   4GB
# 229       IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz  16GB
#
#                     Memory                      Gpu       OpSys  Weight  \
# 28               256GB SSD           AMD Radeon 530  Windows 10   2.2kg
# 1160             256GB SSD    Intel HD Graphics 520  Windows 10  1.48kg
# 78                 2TB HDD    Intel HD Graphics 620       No OS   2.2kg
# 23               500GB HDD            AMD Radeon R2       No OS  1.86kg
# 229   256GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10  4.42kg
#
#       Price_in_euros
# 28            800.00
# 1160         1629.00
# 78            519.00
# 23            258.00
# 229          2456.34

# %%
df.describe()
# Out:
#            Inches  Price_in_euros
# count  912.000000      912.000000
# mean    14.981579     1111.724090
# std      1.436719      687.959172
# min     10.100000      174.000000
# 25%     14.000000      589.000000
# 50%     15.600000      978.000000
# 75%     15.600000     1483.942500
# max     18.400000     6099.000000

# %%
target= ['Price_in_euros']

# %%
import matplotlib.pyplot as plt  
import seaborn as sns  

plt.figure(figsize=(8, 5))  
sns.histplot(df['Price_in_euros'], bins=30, kde=True)  
plt.xlabel('Precio en Euros')  
plt.ylabel('Frecuencia')  
plt.title('Distribución de Precios de Portátiles')  
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])

# Calcular correlaciones con la variable target
correlations = numeric_df.corr()['Price_in_euros'].drop('Price_in_euros')

# Ordenar por valor absoluto de mayor a menor
correlations_sorted = correlations.abs().sort_values(ascending=False)

# Mostrar el resultado
print(correlations_sorted)
# Out:
# Inches    0.071043
# Name: Price_in_euros, dtype: float64

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_in_euros'],
#       dtype='object')

# %%
# Seleccionar columnas categóricas (no numéricas)
categorical_cols = df.select_dtypes(exclude=['number']).columns  

# Mostrar valores únicos para cada columna categórica
for col in categorical_cols:
    print(f"Valores únicos en '{col}':\n", df[col].unique(), "\n")
# Out:
# Valores únicos en 'Company':
#  ['HP' 'Dell' 'Apple' 'Lenovo' 'MSI' 'Toshiba' 'Acer' 'Chuwi' 'Asus'
#  'Huawei' 'Razer' 'Mediacom' 'Google' 'Samsung' 'Xiaomi' 'Microsoft'
#  'Vero' 'LG' 'Fujitsu']
#
# Valores únicos en 'Product':
#  ['250 G6' 'Inspiron 7559' 'ProBook 450' 'Macbook Air' 'Inspiron 3567'
#  'ProBook 650' 'Envy 13-AD007nv' 'IdeaPad 320-15IKB' 'GL72M 7REX'
#  'Thinkpad T570' 'MacBook Pro' 'Ideapad 320-15IKBR' 'IdeaPad 320-15IAP'
#  'Portege Z30-C-16P' 'Latitude 5590' 'IdeaPad 110-15IBR' 'GP72MVR 7RFX'
#  'ThinkPad X1' 'GL62 6QF' 'Portege X30-D-10X' 'Chromebook 11'
#  'Inspiron 5567' 'IdeaPad 510s-14IKB' 'LapBook 15.6"' 'GE62 Apache'
#  'ZBook 17' 'Inspiron 7567' 'VivoBook Pro' 'Pro P2540UA-XO0198T'
#  'Thinkpad 13' 'MateBook X' 'Vostro 5568' '250 G5' 'EliteBook 840'
#  'Inspiron 7570' 'IdeaPad Y700-15ISK' 'ThinkPad P51' 'IdeaPad 320-15IKBN'
#  'Portege Z30-C-1CV' 'XPS 13' 'IdeaPad 510-15IKB'
#  '15-bs002nv (i3-6006U/4GB/128GB/FHD/W10)' 'Blade Pro' 'Rog Strix'
#  'ProBook 440' '15-AC110nv (i7-6500U/6GB/1TB/Radeon' 'Probook 440'
#  'FX753VD-GC071T (i7-7700HQ/8GB/1TB/GeForce' 'GS73VR 7RG'
#  'IdeaPad 320-15ISK' 'Inspiron 3552' 'MacBook 12"'
#  '15-bs012nv (i7-7500U/8GB/1TB/Radeon' 'Rog GL553VE-DS74' 'Elitebook 840'
#  'Legion Y520-15IKBN' 'EliteBook 1040' '15-BW091ND (A9-9420/6GB/1TB'
#  'Precision 3520' 'ThinkPad P40' 'Chromebook 14' 'ThinkPad T570'
#  'Latitude 5580' 'ThinkPad L460' 'Yoga Book' 'Spin SP111-31'
#  'Omen 17-W295' 'Inspiron 5577' 'SmartBook 130' 'Vostro 3568'
#  'ProBook 640' 'EliteBook 850' 'FX550IK-DM018T (FX-9830P/8GB/1TB/Radeon'
#  'Inspiron 3168' 'ThinkPad Yoga' 'GT80S 6QE' 'Inspiron 7560'
#  'Thinkpad X270' 'Thinkpad L560' 'ZBook 15u' 'ThinkPad E580'
#  'Pixelbook (Core' 'Notebook 9' 'Thinkpad T470p' 'Thinkpad T460'
#  'IdeaPad 100S-14IBR' '14-am079na (N3710/8GB/2TB/W10)' 'Inspiron 7577'
#  'SmartBook 141' 'GS60 Ghost' 'Aspire A315-51' 'IdeaPad 320-15AST'
#  'Inspiron 7378' 'FX502VM-DM105T (i7-6700HQ/8GB/1TB/GeForce'
#  '15-BS078nr (i7-7500U/8GB/1TB/W10)' 'Latitude E5270' 'IdeaPad 320-15ABR'
#  'Mi Notebook' 'Aspire ES1-531' 'Aspire E5-475' 'ProBook 430'
#  'Alienware 17' 'XPS 15' 'Yoga 500-14ISK' 'Aspire 3' 'Pavilion Power'
#  'Ideapad 520-15IKBR' 'Spectre Pro' 'Portégé Z30-C-188' 'GS63VR 7RG'
#  'Aspire A515-51G' 'VivoBook Max' 'X541NA-GO121 (N4200/4GB/1TB/Linux)'
#  'GE72MVR 7RG' 'GE73VR 7RE' 'VivoBook X540YA-XX519T' 'Yoga 900-13ISK'
#  'VivoBook L402NA' 'IdeaPad 310-15IKB' 'Probook 430' 'Inspiron 5570'
#  'GS40 Phantom' 'GT72S Dominator' 'L502NA-GO052T (N3350/4GB/128GB/W10)'
#  'Tecra A50-C-218' 'ROG Strix' 'Surface Laptop' 'Tecra Z50-C-144'
#  'IdeaPad 110-15ISK' 'Vivobook E200HA' 'Pavilion 15-cb003nv'
#  'Latitude 3180' 'Swift 3' 'V330-15IKB (i3-7130U/4GB/128GB/FHD/W10)'
#  'Inspiron 5370' 'EliteBook 1030' 'ProBook 470' 'IdeaPad 320s-14IKB'
#  'Probook 450' 'Chromebook Flip' 'IdeaPad 720S-14IKB' 'VivoBook S15'
#  'X553SA-XX031T (N3050/4GB/500GB/W10)' 'IdeaPad 320-17IKBR'
#  '15-BW037na (A9-9420/4GB/1TB/Radeon' 'Inspiron 5578' 'Latitude E5570'
#  'Stream 14-AX040wm' 'VivoBook Flip' 'Elitebook 820'
#  '15-bs005nv (i3-6006U/4GB/1TB' 'Spectre x360' 'Chromebook C738T-C2EJ'
#  'Zenbook UX410UA-GV027T' 'ZenBook UX530UQ-PRO' 'SmartBook Edge'
#  'Spectre X360' 'X550VX-XX015D (i5-6300HQ/4GB/1TB/GeForce' 'Latitude 5480'
#  'ZenBook UX305CA-UBM1' 'Aspire E5-576G'
#  'UX410UA-GV350T (i5-8250U/8GB/256GB/FHD/W10)' 'Pavilion 15-AW003nv'
#  'Lapbook 15,6' 'Yoga 720-15IKB' 'ZBook Studio' 'Portege Z30-C-16Z'
#  'Yoga 700-11ISK' '15-ra044nv (N3060/4GB/500GB/W10)' 'Envy 13-AB020nr'
#  'Latitude 3580' 'Inspiron 3576' 'Legion Y720-15IKB' 'EliteBook x360'
#  'Elitebook 850' 'Latitude 7390' '15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)'
#  'IdeaPad 320-17IKB' 'Chromebook C202SA' 'Nitro AN515-51'
#  'Envy 13-AB077cl' 'Satellite Pro' 'Spectre 13-V100nv' 'MacBook Air'
#  'ZenBook Flip' 'Latitude E5470' 'Stream 14-AX000nv' 'EliteBook 820'
#  'Ideapad 700-15ISK' 'Omen 17-AN010nv' 'ThinkPad T470s'
#  'Q304UA-BHI5T11 (i5-7200U/6GB/1TB/FHD/W10)'
#  '15-bs078cl (i7-7500U/8GB/2TB/W10)' 'GT73VR Titan' 'Rog GL753VD-GC082T'
#  'Yoga 720-13IKB' 'Latitude 3570' 'Chromebook C910-C2ST'
#  'Stream 14-AX001nv' '15-bs053od (i7-7500U/6GB/1TB/W10)' 'Latitude 7480'
#  'Aspire 7' 'Rog GL753VD-GC042T' '15-bw000nv (E2-9000e/4GB/500GB/Radeon'
#  'Inspiron 5770' 'GL553VE-FY082T (i7-7700HQ/8GB/1TB'
#  '15-bs025nv (i5-7200U/8GB/256GB/W10)' 'V142 (X5-Z8350/2GB/32GB/W10)'
#  'VivoBook E201NA' 'Precision 7720'
#  'ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)'
#  'E402WA-GA007T (E2-6110/4GB/64GB/W10' 'Chromebook 15' 'Aspire ES1-572'
#  'V310-15ISK (i3-6006U/4GB/500GB/No' 'Thinkpad T470'
#  'R417NA-RS01 (N3350/4GB/32GB/W10)' 'Inspiron 5579' 'Aspire A315-31'
#  'IdeaPad Y910-17ISK' '320-15ISK (i3-6006U/4GB/1TB/GeForce'
#  'Tecra A50-C-1ZV' 'Ideapad 320-15ISK'
#  '15-rb013nv (E2-9000e/4GB/500GB/W10)' 'F756UX-T4201D (i7-7500U/8GB/128GB'
#  'Tecra Z40-C-161' 'ROG GL553VE-FY022' 'Stream 11-Y000na' 'Pavilion X360'
#  'Precision 3510' 'R558UA-DM966T (i5-7200U/8GB/128GB/FHD/W10)'
#  '15-AY023na (N3710/8GB/2TB/W10)' 'Pavilion 15-CK000nv'
#  'Rog GL752VW-T4308T' 'Rog GL552VW-DM201T' 'ThinkPad T460s'
#  'V510-15IKB (i5-7200U/8GB/256GB/FHD/No'
#  'X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)'
#  'V110-15ISK (i5-6200U/4GB/500GB/W10)'
#  'FX753VE-GC093 (i7-7700HQ/12GB/1TB/GeForce' 'Yoga 920-13IKB'
#  'X553SA-XX021T (N3050/4GB/500GB/W10)' 'GE63VR 7RF'
#  'V330-15IKB (i5-8250U/4GB/256GB/FHD/W10)' 'Rog G752VS-BA171T'
#  'Elitebook Folio' 'Ideapad 320-15IAP' 'Vostro 3559' 'Spin 3'
#  'Latitude 5490' 'GL62M (i5-7300HQ/8GB/1TB'
#  'Q534UX-BHI7T19 (i7-7500U/16GB/2TB' 'Zenbook UX430UA' 'Predator 17'
#  'Aspire ES1-533' 'ThinkPad 13' 'K147 (N3350/4GB/32GB/FHD/W10)'
#  'Omen 17-an012dx' 'Aspire A515-51G-59QF' 'ROG G701VO'
#  'E402WA-GA010T (E2-6110/2GB/32GB/W10)' 'Swift SF114-31-P5HY'
#  'Pro P2540UA-XO0192R' 'Rog GL753VE-DS74' 'Chromebook X360'
#  'V310-15ISK (i3-6006U/4GB/1TB/FHD/W10)' 'IdeaPad 310-15ISK'
#  'L403NA-GA013TS (N3350/4GB/32GB/W10)'
#  'X751NV-TY001 (N4200/4GB/1TB/GeForce' 'Tecra A50-D-11D'
#  'V110-15IKB (i5-7200U/4GB/128GB/W10)' 'Tecra A40-C-1E5' 'Omen -'
#  'FX502VM-AS73 (i7-7700HQ/16GB/1TB' 'ThinkPad E480'
#  'X751SV-TY001T (N3710/4GB/1TB/GeForce' 'Thinkpad E470'
#  'V110-15ISK (3855U/4GB/500GB/W10)'
#  'X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce' 'EliteBook Folio'
#  'Pro P2540UA-XS51' 'IdeaPad 310-15ABR' 'GL72M 7RDX' 'Rog GL502VS'
#  'FX553VD-FY647T (i7-7700HQ/8GB/256GB/GeForce' 'Inspiron 5378'
#  'TravelMate P259-G2' 'ThinkPad L570'
#  'X541NA-PD1003Y (N4200/4GB/500GB/W10)' 'GT62VR 7RE' 'GE72VR Apache'
#  'Inspiron 5379' 'Probook 650' 'N42-20 Chromebook'
#  'X751NV-TY001T (N4200/4GB/1TB/GeForce' 'ThinkPad T560' 'Thinkpad T460p'
#  'IdeaPad 510-15ISK' 'Aspire A517-51G'
#  'X505BP-BR019T (A9-9420/4GB/1TB/Radeon'
#  'UX430UQ-GV209R (i7-7500U/8GB/256GB/GeForce'
#  'V110-15ISK (i5-6200U/4GB/128GB/W10)' 'Latitude 7280'
#  '15-bs190od (i5-8250U/4GB/1TB/W10)' 'Rog G752VY-GC229T'
#  'V110-15ISK (i5-6200U/4GB/500GB/No' 'Thinkpad T460s' 'VivoBook S14'
#  'GS70 Stealth' 'Blade Stealth' 'Notebook Odyssey'
#  'FX553VD-DM627T (i5-7300HQ/8GB/1TB' 'GL62M 7REX' 'VivoBook E12'
#  'Alienware 15' 'SmartBook 140' 'UX510UX-CN269T (i7-7500U/8GB/256GB'
#  'Laptop MSI' '255 G6' 'Yoga 500-15ISK' 'Zenbook 3' 'Omen 17-an006nv'
#  'GT80S 6QF-074US' 'X705UV-BX074T (i3-6006U/4GB/1TB/GeForce'
#  'Portege Z30-C-16L' 'GV62M 7RD' 'Thinkpad X1' 'GP62M Leopard'
#  'V110-15IAP (N3350/4GB/1TB/No' 'Nitro 5' 'ThinkPad T460' 'Chromebook N23'
#  'Thinkpad P51' 'TMX349-G2-M-50FS (i5-7200U/8GB/256GB/FHD/W10)'
#  'ThinkPad E570' 'ROG G703VI-E5062T'
#  'CB5-132T-C9KK (N3160/4GB/32GB/Chrome' 'Inspiron 5368' 'ThinkPad X270'
#  'FX753VE-GC155T (i7-7700HQ/16GB/1TB'
#  '15-ay047nv (i3-6006U/6GB/1TB/Radeon' 'Omen 17-w212nv'
#  'K756UX-T4340T (i5-7200U/8GB/500GB' 'IdeaPad 520S-14IKB'
#  'IdeaPad 120S-14IAP' 'VivoBook E403NA' 'C740-C9QX (3205U/2GB/32GB/Chrome'
#  'X540SA-RBPDN09 (N3710/4GB/1TB/W10)' 'Pro P2540UA-AB51'
#  'A541NA-GO342 (N3350/4GB/500GB/Linux)' 'GE72 Apache'
#  '15-cd005nv (A9-9420/6GB/256GB/Radeon' 'Thinkpad T470s'
#  '15-BW094nd (A6-9220/8GB/128GB/W10)' 'GP62M 7REX' 'ZenBook 3'
#  'Aspire E5-774G' 'GT73EVR 7RE' 'Spin 5' 'Leopard GP72M' 'Chromebook 13'
#  'Portege X30-D-10L' 'V310-15ISK (i3-6006U/4GB/128GB/FHD/No'
#  'IdeaPad 320-14IAP' 'Aspire F5-573G-510L' 'Noteb Pav' 'IdeaPad 300-17ISK'
#  'Rog GL502VM-DS74' 'B51-80 (i7-6500U/8GB/1008GB/Radeon' 'Omen 15-AX205na'
#  'X555QG-DM242T (A10-9620P/4GB/1TB' 'Envy 13-ad009n' 'Tecra A40-C-1DF'
#  'Omen 17-W006na' 'Inspiron 5568' 'Rog GL702VS-GC095T'
#  'V310-15IKB (i5-7200U/8GB/1TB' 'GV62 7RD-1686NL' 'ThinkPad L470'
#  'Yoga 900S-12ISK' 'Predator G9-793' 'ROG GL703VD-GC028T'
#  'Rog GL753VE-GC070T' 'V330-15IKB (i5-8250U/4GB/500GB/FHD/W10)'
#  'IdeaPad Y900-17ISK' 'Yoga 520-14IKB' 'Latitude 3380'
#  '17-BS092ND (i3-6006U/8GB/256GB/W10)' 'GE63VR 7RE' 'PL60 7RD'
#  'V310-15ISK (i5-7200U/4GB/1TB/FHD/W10)' 'Rog GL553VE-FY052T'
#  'Probook 640' 'Gram 15Z975' 'Omen 15-ce006nv' 'Portege X30-D-10K'
#  '17-bs001nv (i5-7200U/6GB/2TB/Radeon' 'Zbook 15' 'Lifebook A557'
#  'Precision 5520' 'Inspiron 3179' '15-bw009nv (A12-9720P/6GB/1TB/Radeon'
#  'ZenBook UX510UX-CN211T' 'GS63VR 7RF' 'Portege Z30-C-16H'
#  'Aspire VX5-591G' 'Zenbook UX510UW-FI095T'
#  '15-bw011nv (A6-9220/4GB/1TB/FHD/W10)' 'Thinkpad P71'
#  '15-bw002nv (A6-9220/4GB/256GB/Radeon'
#  'V310-15IKB (i5-7200U/4GB/1TB/FHD/W10)' 'Aspire 5' 'Rog GL702VS-BA023T'
#  'Probook 470' 'E5 774G' 'TravelMate B' 'Portege Z30T-C-133'
#  '15-bw007nv (A10-9620P/6GB/128GB/Radeon' 'X541NA (N4200/4GB/1TB/W10)'
#  'G752VY-GC162T (i7-6700HQ/16GB/1TB' 'GE73VR 7RF'
#  'V320-17ISK (i3-6006U/4GB/500GB/FHD/No' 'Yoga 510-15IKB' 'Envy x360'
#  'Zbook 17' 'Thinkpad E570' 'Portégé Z30-C-16K' 'ZenBook UX430UA'
#  'IdeaPad 520s-14IKB' 'Aspire E5-575' 'Aspire R7' 'Vostro 5370'
#  'Aspire F5-573G' 'Latitude E7470' 'Tecra A50-D-11M' 'Portege X30-D-10J'
#  'X542UQ-DM117 (i3-7100U/8GB/1TB/GeForce' 'Chromebook C731-C78G'
#  'TP501UA-CJ131T (i5-7200U/8GB/1TB/W10)' 'Inspiron 7779' 'Thinkpad Yoga'
#  'Aspire ES1-523' 'Tecra A50-C-21G' 'Vostro 5468' 'ZenBook UX430UN'
#  '15-BW004nv (A9-9420/4GB/256GB/Radeon'
#  'FX753VD-GC007T (i7-7700HQ/8GB/1TB'
#  'X542UQ-GO005 (i5-7200U/8GB/1TB/GeForce' 'LifeBook A557' 'Latitude 3480'
#  'ZenBook UX410UA-GV183T' 'Omen 15-ce007nv' 'Smartbook 142'
#  'Tecra X40-D-10G' 'X541NA-GO414T (N3350/8GB/1TB/W10)' 'GP72VR Leopard'
#  'Portege Z30-C-1CW' 'Chromebook 3' 'Zenbook UX390UA' '17-bs000nv I3'
#  'ZBook 15' 'SP315-51 (i7-7500U/12GB/1TB/FHD/W10)' 'Portege X20W-D-10V'
#  '17-BS037cl (i3-6006U/8GB/1TB/W10)' 'Extensa EX2540-58KR'
#  'Omen 17-w207nv' 'Zenbook Flip' 'V110-15ISK (i3-6006U/4GB/1TB/Radeon'
#  'Lenovo IdeaPad' 'TravelMate B117-M'
#  '15-BS026nv (i5-7200U/8GB/256GB/Radeon' 'Rog GL552VW-CN470T'
#  'Latitude E7270' 'ENVY -' 'Inspiron 7773' 'Aspire A515-51G-37JS'
#  '110-15ACL (A6-7310/4GB/500GB/W10)' 'Rog G752VL-UH71T' 'Vivobook Max'
#  'GL62M 7RD']
#
# Valores únicos en 'TypeName':
#  ['Notebook' 'Gaming' 'Ultrabook' 'Workstation' 'Netbook'
#  '2 in 1 Convertible']
#
# Valores únicos en 'ScreenResolution':
#  ['Full HD 1920x1080' '1440x900' '1366x768' 'IPS Panel Full HD 1920x1080'
#  'IPS Panel 4K Ultra HD 3840x2160' 'IPS Panel Retina Display 2560x1600'
#  'Touchscreen 1366x768' 'IPS Panel Quad HD+ 2560x1440'
#  'IPS Panel 1366x768' 'Full HD / Touchscreen 1920x1080'
#  'IPS Panel Full HD 2160x1440' 'Quad HD+ 3200x1800'
#  '4K Ultra HD / Touchscreen 3840x2160'
#  'IPS Panel Retina Display 2304x1440'
#  'IPS Panel Full HD / Touchscreen 1920x1080'
#  'IPS Panel Touchscreen 1920x1200' 'IPS Panel Touchscreen 2560x1440'
#  'Touchscreen 2400x1600' 'IPS Panel 4K Ultra HD / Touchscreen 3840x2160'
#  'IPS Panel Full HD 2560x1440' 'Quad HD+ / Touchscreen 3200x1800'
#  '4K Ultra HD 3840x2160' 'IPS Panel Quad HD+ / Touchscreen 3200x1800'
#  'Touchscreen 2256x1504' '1600x900' 'IPS Panel Touchscreen 1366x768'
#  'Touchscreen / Quad HD+ 3200x1800' 'IPS Panel 2560x1440'
#  'IPS Panel Quad HD+ 3200x1800' 'Touchscreen 2560x1440' '2560x1440'
#  'IPS Panel Retina Display 2880x1800'
#  'Touchscreen / 4K Ultra HD 3840x2160' '1920x1080'
#  'Touchscreen / Full HD 1920x1080' 'IPS Panel Full HD 1920x1200']
#
# Valores únicos en 'Cpu':
#  ['Intel Core i3 6006U 2GHz' 'Intel Core i7 6700HQ 2.6GHz'
#  'Intel Core i7 7500U 2.7GHz' 'Intel Core i5 1.8GHz'
#  'Intel Core i3 6006U 2.0GHz' 'Intel Core i5 7300U 2.6GHz'
#  'Intel Core i5 7200U 2.5GHz' 'Intel Core i3 7100U 2.4GHz'
#  'Intel Core i7 7700HQ 2.8GHz' 'Intel Core i7 7600U 2.8GHz'
#  'Intel Core i5 2.9GHz' 'Intel Core i7 8550U 1.8GHz'
#  'Intel Pentium Quad Core N4200 1.1GHz' 'Intel Core i7 6500U 2.5GHz'
#  'Intel Core i7 8650U 1.9GHz' 'Intel Celeron Quad Core N3710 1.6GHz'
#  'Intel Celeron Dual Core N3060 1.6GHz' 'Intel Atom x5-Z8300 1.44GHz'
#  'Intel Core i5 7300HQ 2.5GHz' 'Intel Pentium Quad Core N3710 1.6GHz'
#  'Intel Core i5 6200U 2.3GHz' 'Intel Core i5 8250U 1.6GHz'
#  'AMD Ryzen 1700 3GHz' 'Intel Core i7 7820HK 2.9GHz'
#  'Intel Core i5 1.3GHz' 'Intel Pentium Quad Core N3700 1.6GHz'
#  'AMD A9-Series A9-9420 3GHz' 'Intel Core i7 7560U 2.4GHz'
#  'Intel Core i7 6600U 2.6GHz' 'Intel Celeron Dual Core 3855U 1.6GHz'
#  'Intel Atom x5-Z8550 1.44GHz' 'Intel Core i5 3.1GHz'
#  'Intel Celeron Dual Core N3350 2.0GHz' 'Intel Atom x5-Z8350 1.44GHz'
#  'AMD FX 9830P 3GHz' 'Intel Core i7 6820HK 2.7GHz'
#  'Intel Core i7 7Y75 1.3GHz' 'Intel Celeron Dual Core N3050 1.6GHz'
#  'AMD A6-Series 9220 2.9GHz' 'Intel Core i3 6100U 2.3GHz'
#  'AMD A12-Series 9720P 3.6GHz' 'Intel Core i5 6300U 2.4GHz'
#  'AMD E-Series 7110 1.8GHz' 'Intel Celeron Dual Core N3350 1.1GHz'
#  'Intel Core M m3-7Y30 2.2GHz' 'Intel Core i3 7130U 2.7GHz'
#  'Intel Core M 6Y54 1.1GHz' 'Intel Core i5 7500U 2.7GHz'
#  'Intel Core M M7-6Y75 1.2GHz' 'Intel Core M 6Y75 1.2GHz'
#  'AMD A9-Series 9420 3GHz' 'Intel Celeron Quad Core N3450 1.1GHz'
#  'Intel Core i5 6300HQ 2.3GHz' 'Intel Core M M3-6Y30 0.9GHz'
#  'Intel Core i5 7440HQ 2.8GHz' 'Intel Core i5 2.0GHz'
#  'Intel Core M 6Y30 0.9GHz' 'AMD A9-Series 9410 2.9GHz'
#  'Intel Core M m7-6Y75 1.2GHz' 'Intel Core i5 1.6GHz'
#  'Intel Core i7 6820HQ 2.7GHz' 'Intel Celeron Dual Core 3205U 1.5GHz'
#  'AMD E-Series E2-9000e 1.5GHz' 'Intel Core i5 7Y54 1.2GHz'
#  'Intel Atom X5-Z8350 1.44GHz' 'Intel Xeon E3-1505M V6 3GHz'
#  'Intel Core i7 7820HQ 2.9GHz' 'AMD A8-Series 7410 2.2GHz'
#  'AMD E-Series 6110 1.5GHz' 'Intel Core M m3 1.2GHz' 'Intel Core M 1.1GHz'
#  'Intel Core i7 7660U 2.5GHz' 'AMD E-Series 9000e 1.5GHz'
#  'Intel Core i7 6560U 2.2GHz' 'Intel Core i5 6440HQ 2.6GHz'
#  'AMD E-Series E2-6110 1.5GHz' 'AMD A10-Series 9600P 2.4GHz'
#  'AMD E-Series E2-9000 2.2GHz' 'Intel Core i7 2.2GHz'
#  'Intel Core i5 7Y57 1.2GHz' 'Intel Celeron Quad Core N3160 1.6GHz'
#  'Intel Core i3 6100U 2.1GHz' 'AMD A6-Series 9220 2.5GHz'
#  'Intel Core i7 7500U 2.5GHz' 'Intel Core i7 6920HQ 2.9GHz'
#  'Intel Celeron Dual Core N3350 2GHz' 'Intel Core i7 2.7GHz'
#  'AMD A6-Series A6-9220 2.5GHz' 'Intel Core i7 7700HQ 2.7GHz'
#  'Intel Core i5 6260U 1.8GHz' 'Intel Pentium Dual Core 4405Y 1.5GHz'
#  'AMD A9-Series 9420 2.9GHz' 'AMD A10-Series A10-9620P 2.5GHz'
#  'Intel Core M 1.2GHz' 'Intel Core M 7Y30 1.0GHz'
#  'AMD A12-Series 9720P 2.7GHz' 'AMD A10-Series 9620P 2.5GHz'
#  'Intel Core i7 2.8GHz' 'AMD Ryzen 1600 3.2GHz'
#  'Intel Xeon E3-1535M v5 2.9GHz' 'Intel Core i5 2.3GHz'
#  'Intel Pentium Dual Core 4405U 2.1GHz' 'Intel Core i3 6006U 2.2GHz'
#  'Intel Atom Z8350 1.92GHz' 'Intel Core i5 7200U 2.50GHz'
#  'AMD A6-Series 7310 2GHz' 'Intel Pentium Dual Core N4200 1.1GHz']
#
# Valores únicos en 'Ram':
#  ['8GB' '16GB' '4GB' '12GB' '32GB' '6GB' '2GB' '64GB' '24GB']
#
# Valores únicos en 'Memory':
#  ['256GB SSD' '1TB HDD' '128GB Flash Storage' '128GB SSD +  1TB HDD'
#  '512GB SSD' '500GB HDD' '256GB SSD +  256GB SSD' '128GB SSD'
#  '32GB Flash Storage' '64GB Flash Storage' '1.0TB Hybrid' '2TB HDD'
#  '256GB Flash Storage' '256GB SSD +  1TB HDD' '180GB SSD'
#  '16GB Flash Storage' '1TB SSD' '256GB SSD +  2TB HDD' '32GB SSD'
#  '1TB SSD +  1TB HDD' '128GB SSD +  2TB HDD' '512GB SSD +  1TB HDD'
#  '512GB SSD +  512GB SSD' '512GB SSD +  256GB SSD' '16GB SSD'
#  '64GB Flash Storage +  1TB HDD' '64GB SSD' '128GB HDD' '240GB SSD'
#  '512GB SSD +  2TB HDD' '508GB Hybrid' '8GB SSD' '256GB SSD +  500GB HDD'
#  '1.0TB HDD' '512GB Flash Storage' '1TB HDD +  1TB HDD' '32GB HDD']
#
# Valores únicos en 'Gpu':
#  ['Intel HD Graphics 520' 'Nvidia GeForce GTX 960<U+039C>'
#  'Nvidia GeForce 930MX' 'Intel HD Graphics 6000' 'AMD Radeon R5 M430'
#  'Intel HD Graphics 620' 'Nvidia GeForce 940MX'
#  'Nvidia GeForce GTX 1050 Ti' 'Intel Iris Graphics 550'
#  'Intel HD Graphics 505' 'Intel UHD Graphics 620' 'Intel HD Graphics 405'
#  'Nvidia GeForce GTX 1060' 'Nvidia GeForce GTX 960M'
#  'Intel HD Graphics 400' 'AMD Radeon R7 M445' 'AMD Radeon R7 M460'
#  'Intel HD Graphics' 'AMD FirePro W6150M' 'Nvidia GeForce GTX 1050'
#  'Nvidia Quadro M1200' 'AMD Radeon RX 580' 'Nvidia GeForce GTX 1080'
#  'AMD Radeon R5 M330' 'Nvidia GeForce GTX 1070' 'Intel HD Graphics 615'
#  'AMD Radeon 530' 'AMD Radeon 520' 'Nvidia Quadro M620'
#  'Intel Iris Plus Graphics 640' 'Nvidia Quadro M500M'
#  'Intel HD Graphics 510' 'Intel Iris Plus Graphics 650'
#  'Nvidia GeForce 920MX ' 'Intel HD Graphics 500' 'AMD Radeon R5 M420'
#  'AMD Radeon RX 560' 'Nvidia GeForce GTX 980M' 'AMD FirePro W4190M'
#  'AMD Radeon RX 550' 'AMD Radeon 540' 'Nvidia GeForce GT 940MX'
#  'Nvidia GeForce GTX 970M' 'AMD Radeon R4 Graphics' 'AMD Radeon R7'
#  'Nvidia GeForce MX150' 'Nvidia GeForce GTX 1050Ti' 'Nvidia GeForce MX130'
#  'AMD Radeon R2 Graphics' 'Nvidia GeForce 930M' 'Intel Graphics 620'
#  'Intel HD Graphics 515' 'Nvidia GeForce 920MX' 'Nvidia GeForce GTX 1050M'
#  'Nvidia GeForce GTX 950M' 'Intel Iris Graphics 540' 'AMD Radeon R7 M440'
#  'Nvidia Quadro M1000M' 'Nvidia GeForce 150MX' 'AMD Radeon R2'
#  'AMD Radeon R5' 'Intel HD Graphics 5300' 'AMD FirePro W5130M'
#  'Nvidia GeForce GTX 940MX' 'AMD Radeon R5 M420X' 'AMD Radeon R5 M315'
#  'AMD Radeon R7 M365X' 'Nvidia GeForce GTX 980 ' 'Nvidia GeForce GTX 960'
#  'Nvidia GeForce 920M' 'AMD Radeon R5 430' 'Intel Iris Pro Graphics'
#  'Nvidia GeForce GTX 965M' 'Intel HD Graphics 620 ' 'Nvidia GTX 980 SLI'
#  'AMD FirePro W4190M ' 'Nvidia Quadro M3000M' 'Nvidia Quadro M2200M'
#  'AMD Radeon Pro 455' 'Nvidia GeForce GTX1050 Ti' 'Intel HD Graphics 540'
#  'Nvidia GeForce 930MX ' 'AMD R17M-M1-70' 'AMD Radeon R4'
#  'Nvidia Quadro M620M' 'AMD R4 Graphics' 'AMD Radeon RX 540'
#  'AMD Radeon Pro 555' 'Nvidia Quadro M2000M' 'Nvidia GeForce GTX 940M'
#  'Intel HD Graphics 630' 'AMD Radeon R5 520' 'Nvidia GeForce GTX 1070M']
#
# Valores únicos en 'OpSys':
#  ['Windows 10' 'macOS' 'Linux' 'No OS' 'Chrome OS' 'Windows 7' 'Android'
#  'Windows 10 S' 'Mac OS X']
#
# Valores únicos en 'Weight':
#  ['1.86kg' '2.59kg' '2.04kg' '1.34kg' '2.25kg' '2.31kg' '1.32kg' '2.2kg'
#  '2.7kg' '2.3kg' '1.37kg' '1.2kg' '1.88kg' '1.17kg' '1.05kg' '1.35kg'
#  '1.5kg' '1.89kg' '2.4kg' '3.0kg' '2.65kg' '1.99kg' '2.37kg' '1.4kg'
#  '2.36kg' '2.18kg' '1.96kg' '1.54kg' '3.14kg' '1.9kg' '1.13kg' '2.6kg'
#  '2.67kg' '1.3kg' '1.91kg' '1.95kg' '3.25kg' '1.64kg' '1.44kg' '1.26kg'
#  '3.49kg' '2.19kg' '1.63kg' '3kg' '2.43kg' '0.92kg' '2.1kg' '2.5kg'
#  '1.48kg' '1.43kg' '2.06kg' '1.23kg' '1.8kg' '1.45kg' '1.93kg' '2.32kg'
#  '0.69kg' '1.27kg' '1.25kg' '3.35kg' '2.56kg' '2.45kg' '1.47kg' '4.5kg'
#  '2.0kg' '1.36kg' '1.1kg' '1.71kg' '1.21kg' '1.7kg' '1.94kg' '1.14kg'
#  '1.6kg' '1.29kg' '2.05kg' '1.49kg' '4.36kg' '2.62kg' '2.21kg' '1.84kg'
#  '2.17kg' '1.16kg' '2kg' '2.29kg' '2.9kg' '2.8kg' '1.65kg' '3.78kg'
#  '2.73kg' '1.252kg' '0.98kg' '2.20kg' '2.08kg' '2.09kg' '4.42kg' '2.23kg'
#  '1.42kg' '2.13kg' '3.2kg' '1.28kg' '2.07kg' '2.79kg' '0.81kg' '1.39kg'
#  '1.11kg' '1.08kg' '1.22kg' '1.79kg' '4.14kg' '1.98kg' '1.24kg' '3.42kg'
#  '1.90kg' '1.58kg' '0.920kg' '4.6kg' '2.69kg' '1.83kg' '3.52kg' '2.591kg'
#  '4.3kg' '1.09kg' '2.24kg' '2.16kg' '4.2kg' '3.74kg' '3.58kg' '2.99kg'
#  '1.85kg' '1.75kg' '1.87kg' '3.31kg' '0.97kg' '2.34kg' '1.68kg' '2.94kg'
#  '1.62kg' '3.21kg' '4.4kg' '1.70kg' '1.56kg' '2.26kg' '2.02kg' '4.7kg'
#  '2.14kg' '1.10kg' '3.3kg' '1.38kg' '2.75kg' '0.99kg' '2.33kg' '1.74kg'
#  '2.71kg' '2.63kg' '3.4kg' '1.41kg' '2.77kg' '1.76kg' '1.55kg' '1.15kg'
#  '0.91kg' '2.15kg' '2.54kg' '1.18kg' '4.33kg']

# %%
df["inches"]=df.Inches.astype(float)
df["ram_gb"]=df['Ram'].str.replace('GB','').astype(int)
df['weight_kg']=df['Weight'].str.replace('kg','').astype(float)

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_in_euros', 'inches',
#        'ram_gb', 'weight_kg'],
#       dtype='object')

# %%
features_cat_prim=['Company', 'Product', 'TypeName','ScreenResolution', 'Cpu','Gpu', 'OpSys']

# %%
from scipy.stats import f_oneway

# Función para realizar la prueba ANOVA para una columna categórica
def anova_test(df, col):
    # Crear una lista de valores de 'Price_in_euros' para cada categoría en la variable categórica
    groups = [df[df[col] == category]['Price_in_euros'] for category in df[col].unique()]
    
    # Realizar la prueba ANOVA
    f_stat, p_value = f_oneway(*groups)
    
    return p_value  # Retornar el valor p de la prueba

# Aplicar la prueba ANOVA para las variables categóricas
for col in features_cat_prim:
    p_value = anova_test(df, col)
    print(f"Valor p de ANOVA para '{col}': {p_value}")
# Out:
# Valor p de ANOVA para 'Company': 1.870590724382312e-25
# Valor p de ANOVA para 'Product': 7.874518679231296e-108
# Valor p de ANOVA para 'TypeName': 5.614483898088773e-99
# Valor p de ANOVA para 'ScreenResolution': 3.940293313717892e-77
# Valor p de ANOVA para 'Cpu': 8.486815112707918e-121
# Valor p de ANOVA para 'Gpu': 4.705316304392847e-122
# Valor p de ANOVA para 'OpSys': 1.0281069131390438e-19

# %%
# Crear un diccionario para las categorías de marcas
company_group_mapping = {
    'Apple': 'Gama Alta',
    'Microsoft': 'Gama Alta',
    'Razer': 'Gama Alta',
    'Google': 'Gama Alta',
    'LG': 'Gama Alta',
    'Dell': 'Gama Media',
    'Lenovo': 'Gama Media',
    'Asus': 'Gama Media',
    'HP': 'Gama Media',
    'Samsung': 'Gama Media',
    'Acer': 'Gama Baja',
    'Toshiba': 'Gama Baja',
    'Xiaomi': 'Gama Baja',
    'Chuwi': 'Gama Baja',
    'Mediacom': 'Gama Baja',
    'Fujitsu': 'Gama Baja',
    'MSI': 'Gaming/Especializados',
    'Huawei': 'Gama Alta',  # <- Nueva adición
    'Vero': 'Gama Baja'
}

# Aplicar el mapeo de las marcas a la nueva columna
df['Company_Group'] = df['Company'].map(company_group_mapping)

df[['Company', 'Company_Group']].head()
# Out:
#     Company Company_Group
# 755      HP    Gama Media
# 618    Dell    Gama Media
# 909      HP    Gama Media
# 2     Apple     Gama Alta
# 286    Dell    Gama Media

# %%
# Crear un diccionario para el mapeo de las nuevas categorías
type_name_mapping = {
    'Gaming': 'Alto rendimiento',
    'Workstation': 'Alto rendimiento',
    'Notebook': 'Intermedio',
    'Ultrabook': 'Intermedio',
    'Netbook': 'Bajo rendimiento',
    '2 in 1 Convertible': 'Bajo rendimiento'
}

# Reemplazar los valores de 'TypeName' con las nuevas categorías
df['TypeName_Group'] = df['TypeName'].map(type_name_mapping)

# Convertir las nuevas categorías en valores numéricos
type_name_group_numerical = {
    'Alto rendimiento': 3,
    'Intermedio': 2,
    'Bajo rendimiento': 1
}

# Aplicar el mapeo numérico
df['TypeName_Group_Num'] = df['TypeName_Group'].map(type_name_group_numerical)

# Ver el resultado
print(df[['TypeName', 'TypeName_Group', 'TypeName_Group_Num']].head())
# Out:
#       TypeName    TypeName_Group  TypeName_Group_Num
# 755   Notebook        Intermedio                   2
# 618     Gaming  Alto rendimiento                   3
# 909   Notebook        Intermedio                   2
# 2    Ultrabook        Intermedio                   2
# 286   Notebook        Intermedio                   2

# %%
import re

# Función para extraer el tamaño total en GB
def extract_total_gb(memory):
    # Inicializamos el tamaño total
    total_gb = 0
    
    # Separamos por "+" en caso de que haya varias combinaciones
    memory_items = memory.split('+')
    
    for item in memory_items:
        # Extraemos el tamaño (en GB o TB) y unidad
        match = re.match(r'(\d+\.?\d*)\s*(GB|TB)', item.strip())
        if match:
            size = float(match.group(1))  # Tamaño numérico
            unit = match.group(2)  # Unidad (GB o TB)
            
            # Si es TB, lo convertimos a GB
            if unit == 'TB':
                size *= 1024  # Convertir a GB
            total_gb += size  # Sumamos el tamaño total en GB
    
    return total_gb

# Aplicar las funciones a la columna 'Memory' para crear las nuevas columnas
df['Total_GB'] = df['Memory'].apply(extract_total_gb)
df[['Memory', 'Total_GB']]
# Out:
#                     Memory  Total_GB
# 755              256GB SSD     256.0
# 618                1TB HDD    1024.0
# 909                1TB HDD    1024.0
# 2      128GB Flash Storage     128.0
# 286                1TB HDD    1024.0
# ...                    ...       ...
# 28               256GB SSD     256.0
# 1160             256GB SSD     256.0
# 78                 2TB HDD    2048.0
# 23               500GB HDD     500.0
# 229   256GB SSD +  1TB HDD    1280.0
#
# [912 rows x 2 columns]

# %%
def extract_disk_types(memory):
    # Lista de posibles tipos de disco
    possible_types = ['SSD', 'HDD', 'Flash', 'Hybrid']
    
    # Extraemos los tipos presentes en la cadena
    disk_types = [disk for disk in possible_types if disk in memory]
    
    return ', '.join(disk_types)  
df['Disk_Types'] = df['Memory'].apply(extract_disk_types)
df[['Memory', 'Total_GB', 'Disk_Types']]
# Out:
#                     Memory  Total_GB Disk_Types
# 755              256GB SSD     256.0        SSD
# 618                1TB HDD    1024.0        HDD
# 909                1TB HDD    1024.0        HDD
# 2      128GB Flash Storage     128.0      Flash
# 286                1TB HDD    1024.0        HDD
# ...                    ...       ...        ...
# 28               256GB SSD     256.0        SSD
# 1160             256GB SSD     256.0        SSD
# 78                 2TB HDD    2048.0        HDD
# 23               500GB HDD     500.0        HDD
# 229   256GB SSD +  1TB HDD    1280.0   SSD, HDD
#
# [912 rows x 3 columns]

# %%
# Función para categorizar los tipos de disco
def categorize_disk_type(disk_type):
    single_types = {'SSD', 'HDD', 'Flash'}  # Tipos individuales permitidos
    disk_list = disk_type.split(', ')  # Convertir en lista
    
    # Si solo hay un tipo y está en los permitidos, mantenerlo
    if len(disk_list) == 1 and disk_list[0] in single_types:
        return disk_list[0]
    
    # Si hay más de un tipo, clasificarlo como 'Hybrid'
    return 'Hybrid'

# Aplicamos la función a la columna 'Disk_Types'
df['Disk_Types'] = df['Disk_Types'].apply(categorize_disk_type)

# Ver el resultado
print(df[['Memory', 'Total_GB', 'Disk_Types']].head())
# Out:
#                   Memory  Total_GB Disk_Types
# 755            256GB SSD     256.0        SSD
# 618              1TB HDD    1024.0        HDD
# 909              1TB HDD    1024.0        HDD
# 2    128GB Flash Storage     128.0      Flash
# 286              1TB HDD    1024.0        HDD

# %%
print(df['Disk_Types'].unique())
# Out:
# ['SSD' 'HDD' 'Flash' 'Hybrid']

# %%
import re

# Función para extraer el número de píxeles de la resolución
def extract_pixels(screen_resolution):
    # Buscar el formato 'Ancho x Alto' (por ejemplo, 1920x1080)
    match = re.search(r'(\d+)x(\d+)', screen_resolution)
    
    if match:
        # Multiplicamos las dimensiones para obtener el total de píxeles
        width = int(match.group(1))
        height = int(match.group(2))
        return width * height  # Número total de píxeles
    return 0  # Si no se encuentra una resolución válida

# Función para extraer la categoría de la resolución (como 'Full HD', '4K', etc.)
def extract_resolution_type(screen_resolution):
    # Buscar la parte de la resolución que es la etiqueta (ej. 'Full HD', '4K', etc.)
    # El texto aparece antes de la resolución de píxeles
    match = re.search(r'([A-Za-z\s]+)(\d{4}x\d{3,4})', screen_resolution)
    
    if match:
        return match.group(1).strip()  # El nombre de la resolución, por ejemplo 'Full HD'
    return 'Unknown'  # Si no se puede extraer, ponemos 'Unknown'

# Aplicar las funciones a la columna 'ScreenResolution'
df['Screen_Resolution_Pixels'] = df['ScreenResolution'].apply(extract_pixels)
df['Screen_Resolution_Type'] = df['ScreenResolution'].apply(extract_resolution_type)

# Ver los resultados
print(df[['ScreenResolution', 'Screen_Resolution_Pixels', 'Screen_Resolution_Type']].head())
# Out:
#       ScreenResolution  Screen_Resolution_Pixels Screen_Resolution_Type
# 755  Full HD 1920x1080                   2073600                Full HD
# 618  Full HD 1920x1080                   2073600                Full HD
# 909  Full HD 1920x1080                   2073600                Full HD
# 2             1440x900                   1296000                Unknown
# 286  Full HD 1920x1080                   2073600                Full HD

# %%
import pandas as pd
import re

# Función para separar la marca, modelo y frecuencia
def extract_cpu_info(cpu):
    # Identificar la marca
    if 'Intel' in cpu:
        marca = 'Intel'
    elif 'AMD' in cpu:
        marca = 'AMD'
    else:
        marca = 'Desconocido'

    # Extraer el modelo del procesador (esto incluiría el nombre de la serie y versión)
    modelo = re.sub(r'[0-9]+GHz|GHz|Core|M|Xeon|A[0-9]+|Pentium|Ryzen|Series', '', cpu).strip()

    # Extraer la frecuencia en GHz (si está presente)
    frecuencia = re.search(r'(\d+\.\d+|\d+)GHz', cpu)
    if frecuencia:
        # Quitar la unidad "GHz" y convertir a número flotante
        frecuencia = float(frecuencia.group(1))
    else:
        frecuencia = None  # Si no se encuentra la frecuencia, lo dejamos como None

    return marca, modelo, frecuencia

# Aplicamos la función a la columna Cpu
df[['CPU_Marca', 'CPU_Modelo', 'CPU_Frecuencia']] = df['Cpu'].apply(lambda x: pd.Series(extract_cpu_info(x)))

# Mostramos el DataFrame para ver el resultado
print(df[['CPU_Marca', 'CPU_Modelo', 'CPU_Frecuencia']])
# Out:
#      CPU_Marca           CPU_Modelo  CPU_Frecuencia
# 755      Intel      Intel  i3 6006U             2.0
# 618      Intel  Intel  i7 6700HQ 2.             2.6
# 909      Intel   Intel  i7 7500U 2.             2.7
# 2        Intel         Intel  i5 1.             1.8
# 286      Intel   Intel  i3 6006U 2.             2.0
# ...        ...                  ...             ...
# 28       Intel   Intel  i5 8250U 1.             1.6
# 1160     Intel   Intel  i5 6300U 2.             2.4
# 78       Intel   Intel  i5 7200U 2.             2.5
# 23         AMD    AD E- E2-9000e 1.             1.5
# 229      Intel  Intel  i7 7700HQ 2.             2.8
#
# [912 rows x 3 columns]

# %%
df['CPU_Marca'].unique()
# Out:
# array(['Intel', 'AMD'], dtype=object)

# %%
df
# Out:
#      Company             Product            TypeName  Inches  \
# 755       HP              250 G6            Notebook    15.6
# 618     Dell       Inspiron 7559              Gaming    15.6
# 909       HP         ProBook 450            Notebook    15.6
# 2      Apple         Macbook Air           Ultrabook    13.3
# 286     Dell       Inspiron 3567            Notebook    15.6
# ...      ...                 ...                 ...     ...
# 28      Dell       Inspiron 5570            Notebook    15.6
# 1160      HP         Spectre Pro  2 in 1 Convertible    13.3
# 78    Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 23        HP              255 G6            Notebook    15.6
# 229     Dell        Alienware 17              Gaming    17.3
#
#                      ScreenResolution                           Cpu   Ram  \
# 755                 Full HD 1920x1080      Intel Core i3 6006U 2GHz   8GB
# 618                 Full HD 1920x1080   Intel Core i7 6700HQ 2.6GHz  16GB
# 909                 Full HD 1920x1080    Intel Core i7 7500U 2.7GHz   8GB
# 2                            1440x900          Intel Core i5 1.8GHz   8GB
# 286                 Full HD 1920x1080    Intel Core i3 6006U 2.0GHz   4GB
# ...                               ...                           ...   ...
# 28                  Full HD 1920x1080    Intel Core i5 8250U 1.6GHz   8GB
# 1160  Full HD / Touchscreen 1920x1080    Intel Core i5 6300U 2.4GHz   8GB
# 78                  Full HD 1920x1080    Intel Core i5 7200U 2.5GHz   8GB
# 23                           1366x768  AMD E-Series E2-9000e 1.5GHz   4GB
# 229       IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz  16GB
#
#                     Memory                             Gpu       OpSys  ...  \
# 755              256GB SSD           Intel HD Graphics 520  Windows 10  ...
# 618                1TB HDD  Nvidia GeForce GTX 960<U+039C>  Windows 10  ...
# 909                1TB HDD            Nvidia GeForce 930MX  Windows 10  ...
# 2      128GB Flash Storage          Intel HD Graphics 6000       macOS  ...
# 286                1TB HDD              AMD Radeon R5 M430       Linux  ...
# ...                    ...                             ...         ...  ...
# 28               256GB SSD                  AMD Radeon 530  Windows 10  ...
# 1160             256GB SSD           Intel HD Graphics 520  Windows 10  ...
# 78                 2TB HDD           Intel HD Graphics 620       No OS  ...
# 23               500GB HDD                   AMD Radeon R2       No OS  ...
# 229   256GB SSD +  1TB HDD         Nvidia GeForce GTX 1060  Windows 10  ...
#
#      Company_Group    TypeName_Group  TypeName_Group_Num  Total_GB  \
# 755     Gama Media        Intermedio                   2     256.0
# 618     Gama Media  Alto rendimiento                   3    1024.0
# 909     Gama Media        Intermedio                   2    1024.0
# 2        Gama Alta        Intermedio                   2     128.0
# 286     Gama Media        Intermedio                   2    1024.0
# ...            ...               ...                 ...       ...
# 28      Gama Media        Intermedio                   2     256.0
# 1160    Gama Media  Bajo rendimiento                   1     256.0
# 78      Gama Media        Intermedio                   2    2048.0
# 23      Gama Media        Intermedio                   2     500.0
# 229     Gama Media  Alto rendimiento                   3    1280.0
#
#       Disk_Types Screen_Resolution_Pixels Screen_Resolution_Type  CPU_Marca  \
# 755          SSD                  2073600                Full HD      Intel
# 618          HDD                  2073600                Full HD      Intel
# 909          HDD                  2073600                Full HD      Intel
# 2          Flash                  1296000                Unknown      Intel
# 286          HDD                  2073600                Full HD      Intel
# ...          ...                      ...                    ...        ...
# 28           SSD                  2073600                Full HD      Intel
# 1160         SSD                  2073600            Touchscreen      Intel
# 78           HDD                  2073600                Full HD      Intel
# 23           HDD                  1049088                Unknown        AMD
# 229       Hybrid                  2073600      IPS Panel Full HD      Intel
#
#                CPU_Modelo CPU_Frecuencia
# 755       Intel  i3 6006U            2.0
# 618   Intel  i7 6700HQ 2.            2.6
# 909    Intel  i7 7500U 2.            2.7
# 2            Intel  i5 1.            1.8
# 286    Intel  i3 6006U 2.            2.0
# ...                   ...            ...
# 28     Intel  i5 8250U 1.            1.6
# 1160   Intel  i5 6300U 2.            2.4
# 78     Intel  i5 7200U 2.            2.5
# 23      AD E- E2-9000e 1.            1.5
# 229   Intel  i7 7700HQ 2.            2.8
#
# [912 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company                   912 non-null    object
#  1   Product                   912 non-null    object
#  2   TypeName                  912 non-null    object
#  3   Inches                    912 non-null    float64
#  4   ScreenResolution          912 non-null    object
#  5   Cpu                       912 non-null    object
#  6   Ram                       912 non-null    object
#  7   Memory                    912 non-null    object
#  8   Gpu                       912 non-null    object
#  9   OpSys                     912 non-null    object
#  10  Weight                    912 non-null    object
#  11  Price_in_euros            912 non-null    float64
#  12  inches                    912 non-null    float64
#  13  ram_gb                    912 non-null    int32
#  14  weight_kg                 912 non-null    float64
#  15  Company_Group             912 non-null    object
#  16  TypeName_Group            912 non-null    object
#  17  TypeName_Group_Num        912 non-null    int64
#  18  Total_GB                  912 non-null    float64
#  19  Disk_Types                912 non-null    object
#  20  Screen_Resolution_Pixels  912 non-null    int64
#  21  Screen_Resolution_Type    912 non-null    object
#  22  CPU_Marca                 912 non-null    object
#  23  CPU_Modelo                912 non-null    object
#  24  CPU_Frecuencia            912 non-null    float64
# dtypes: float64(6), int32(1), int64(2), object(16)
# memory usage: 181.7+ KB

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_in_euros', 'inches',
#        'ram_gb', 'weight_kg', 'Company_Group', 'TypeName_Group',
#        'TypeName_Group_Num', 'Total_GB', 'Disk_Types',
#        'Screen_Resolution_Pixels', 'Screen_Resolution_Type', 'CPU_Marca',
#        'CPU_Modelo', 'CPU_Frecuencia'],
#       dtype='object')

# %%
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()
print(numeric_columns)
# Out:
# ['Inches', 'Price_in_euros', 'inches', 'ram_gb', 'weight_kg', 'TypeName_Group_Num', 'Total_GB', 'Screen_Resolution_Pixels', 'CPU_Frecuencia']

# %%
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
print(categorical_columns)
# Out:
# ['Company', 'Product', 'TypeName', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Company_Group', 'TypeName_Group', 'Disk_Types', 'Screen_Resolution_Type', 'CPU_Marca', 'CPU_Modelo']

# %%
features_num=  ['Price_in_euros','inches', 'ram_gb', 'weight_kg', 'TypeName_Group_Num', 'Total_GB', 'Screen_Resolution_Pixels', 'CPU_Frecuencia']

# %%
features_cat=['Product', 'Gpu', 'OpSys', 'Company_Group', 'TypeName_Group', 'Disk_Types', 'Screen_Resolution_Type', 'CPU_Marca', 'CPU_Modelo']

# %%
target= 'Price_in_euros'

# Calcular la correlación de todas las variables numéricas con el target
correlation_target = df[features_num].corr()[target].abs()

# Ordenar los valores de mayor a menor
correlation_target = correlation_target.sort_values(ascending=False)

correlation_target
# Out:
# Price_in_euros              1.000000
# ram_gb                      0.738922
# Screen_Resolution_Pixels    0.493671
# CPU_Frecuencia              0.427116
# TypeName_Group_Num          0.300247
# weight_kg                   0.197086
# Total_GB                    0.184000
# inches                      0.071043
# Name: Price_in_euros, dtype: float64

# %%
corr_matrix = df[features_num].drop(columns=['Price_in_euros']).corr()

# Configurar el tamaño del gráfico
plt.figure(figsize=(10, 8))

# Dibujar el mapa de calor
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)

# Mostrar el gráfico
plt.title("Mapa de calor de correlaciones entre variables numéricas")
plt.show()

# %%
features_num_principales= ['Price_in_euros', 'ram_gb', 'weight_kg', 'TypeName_Group_Num', 'Total_GB', 'Screen_Resolution_Pixels', 'CPU_Frecuencia']

# %%
from scipy.stats import f_oneway

# Función para realizar la prueba ANOVA para una columna categórica
def anova_test(df, col):
    # Crear una lista de valores de 'Price_in_euros' para cada categoría en la variable categórica
    groups = [df[df[col] == category]['Price_in_euros'] for category in df[col].unique()]
    
    # Realizar la prueba ANOVA
    f_stat, p_value = f_oneway(*groups)
    
    return p_value  # Retornar el valor p de la prueba

# Aplicar la prueba ANOVA para las variables categóricas
for col in features_cat:
    p_value = anova_test(df, col)
    print(f"Valor p de ANOVA para '{col}': {p_value}")
# Out:
# Valor p de ANOVA para 'Product': 7.874518679231296e-108
# Valor p de ANOVA para 'Gpu': 4.705316304392847e-122
# Valor p de ANOVA para 'OpSys': 1.0281069131390438e-19
# Valor p de ANOVA para 'Company_Group': 7.162412622468243e-22
# Valor p de ANOVA para 'TypeName_Group': 5.359598156547523e-47
# Valor p de ANOVA para 'Disk_Types': 1.383830694957716e-66
# Valor p de ANOVA para 'Screen_Resolution_Type': 2.4341511622794453e-58
# Valor p de ANOVA para 'CPU_Marca': 8.79374181349309e-08
# Valor p de ANOVA para 'CPU_Modelo': 1.8034243785187906e-127

# %%
# Definir el tamaño de la figura
plt.figure(figsize=(12, 8))

# Iterar sobre cada variable numérica y graficar su histograma
for i, col in enumerate(features_num, 1):
    plt.subplot(3, 3, i)  # Ajusta según el número de variables (filas x columnas)
    plt.hist(df[col], bins=30, edgecolor='black', alpha=0.7)
    plt.title(col)

plt.tight_layout()

# %% [markdown]
# ## Procesado de datos

# %% [markdown]
# Nuestro target es la columna `Price_in_euros`

# %%
df_filtered = df.drop(columns=['CPU_Modelo', 'Screen_Resolution_Type'])

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company                   912 non-null    object
#  1   Product                   912 non-null    object
#  2   TypeName                  912 non-null    object
#  3   Inches                    912 non-null    float64
#  4   ScreenResolution          912 non-null    object
#  5   Cpu                       912 non-null    object
#  6   Ram                       912 non-null    object
#  7   Memory                    912 non-null    object
#  8   Gpu                       912 non-null    object
#  9   OpSys                     912 non-null    object
#  10  Weight                    912 non-null    object
#  11  Price_in_euros            912 non-null    float64
#  12  inches                    912 non-null    float64
#  13  ram_gb                    912 non-null    int32
#  14  weight_kg                 912 non-null    float64
#  15  Company_Group             912 non-null    object
#  16  TypeName_Group            912 non-null    object
#  17  TypeName_Group_Num        912 non-null    int64
#  18  Total_GB                  912 non-null    float64
#  19  Disk_Types                912 non-null    object
#  20  Screen_Resolution_Pixels  912 non-null    int64
#  21  CPU_Marca                 912 non-null    object
#  22  CPU_Frecuencia            912 non-null    float64
# dtypes: float64(6), int32(1), int64(2), object(14)
# memory usage: 167.4+ KB

# %%
df_filtered = df_filtered.iloc[:, 11:].copy()

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Price_in_euros            912 non-null    float64
#  1   inches                    912 non-null    float64
#  2   ram_gb                    912 non-null    int32
#  3   weight_kg                 912 non-null    float64
#  4   Company_Group             912 non-null    object
#  5   TypeName_Group            912 non-null    object
#  6   TypeName_Group_Num        912 non-null    int64
#  7   Total_GB                  912 non-null    float64
#  8   Disk_Types                912 non-null    object
#  9   Screen_Resolution_Pixels  912 non-null    int64
#  10  CPU_Marca                 912 non-null    object
#  11  CPU_Frecuencia            912 non-null    float64
# dtypes: float64(5), int32(1), int64(2), object(4)
# memory usage: 89.1+ KB

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Modelado

# %% [markdown]
# ### 1. Definir X e y

# %%
X = df_filtered.drop(['Price_in_euros'], axis=1)
y = df_filtered['Price_in_euros'].copy()
X.shape
# Out:
# (912, 11)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   inches                    912 non-null    float64
#  1   ram_gb                    912 non-null    int32
#  2   weight_kg                 912 non-null    float64
#  3   Company_Group             912 non-null    object
#  4   TypeName_Group            912 non-null    object
#  5   TypeName_Group_Num        912 non-null    int64
#  6   Total_GB                  912 non-null    float64
#  7   Disk_Types                912 non-null    object
#  8   Screen_Resolution_Pixels  912 non-null    int64
#  9   CPU_Marca                 912 non-null    object
#  10  CPU_Frecuencia            912 non-null    float64
# dtypes: float64(4), int32(1), int64(2), object(4)
# memory usage: 81.9+ KB

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 912 entries, 755 to 229
# Series name: Price_in_euros
# Non-Null Count  Dtype
# --------------  -----
# 912 non-null    float64
# dtypes: float64(1)
# memory usage: 14.2 KB

# %%
X.shape
# Out:
# (912, 11)

# %%
y.shape
# Out:
# (912,)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   inches                    912 non-null    float64
#  1   ram_gb                    912 non-null    int32
#  2   weight_kg                 912 non-null    float64
#  3   Company_Group             912 non-null    object
#  4   TypeName_Group            912 non-null    object
#  5   TypeName_Group_Num        912 non-null    int64
#  6   Total_GB                  912 non-null    float64
#  7   Disk_Types                912 non-null    object
#  8   Screen_Resolution_Pixels  912 non-null    int64
#  9   CPU_Marca                 912 non-null    object
#  10  CPU_Frecuencia            912 non-null    float64
# dtypes: float64(4), int32(1), int64(2), object(4)
# memory usage: 81.9+ KB

# %%
X.copy()
# Out:
#       inches  ram_gb  weight_kg Company_Group    TypeName_Group  \
# 755     15.6       8       1.86    Gama Media        Intermedio
# 618     15.6      16       2.59    Gama Media  Alto rendimiento
# 909     15.6       8       2.04    Gama Media        Intermedio
# 2       13.3       8       1.34     Gama Alta        Intermedio
# 286     15.6       4       2.25    Gama Media        Intermedio
# ...      ...     ...        ...           ...               ...
# 28      15.6       8       2.20    Gama Media        Intermedio
# 1160    13.3       8       1.48    Gama Media  Bajo rendimiento
# 78      15.6       8       2.20    Gama Media        Intermedio
# 23      15.6       4       1.86    Gama Media        Intermedio
# 229     17.3      16       4.42    Gama Media  Alto rendimiento
#
#       TypeName_Group_Num  Total_GB Disk_Types  Screen_Resolution_Pixels  \
# 755                    2     256.0        SSD                   2073600
# 618                    3    1024.0        HDD                   2073600
# 909                    2    1024.0        HDD                   2073600
# 2                      2     128.0      Flash                   1296000
# 286                    2    1024.0        HDD                   2073600
# ...                  ...       ...        ...                       ...
# 28                     2     256.0        SSD                   2073600
# 1160                   1     256.0        SSD                   2073600
# 78                     2    2048.0        HDD                   2073600
# 23                     2     500.0        HDD                   1049088
# 229                    3    1280.0     Hybrid                   2073600
#
#      CPU_Marca  CPU_Frecuencia
# 755      Intel             2.0
# 618      Intel             2.6
# 909      Intel             2.7
# 2        Intel             1.8
# 286      Intel             2.0
# ...        ...             ...
# 28       Intel             1.6
# 1160     Intel             2.4
# 78       Intel             2.5
# 23         AMD             1.5
# 229      Intel             2.8
#
# [912 rows x 11 columns]

# %%
X = pd.get_dummies(X, columns=['Company_Group', 'TypeName_Group', 'Disk_Types', 'CPU_Marca'])

# %% [markdown]
# ### 2. Dividir X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
X_train
# Out:
#       inches  ram_gb  weight_kg  TypeName_Group_Num  Total_GB  \
# 1118    17.3       8       3.00                   3    1024.0
# 153     15.6      16       2.56                   3     512.0
# 275     13.3       8       1.37                   2     512.0
# 1100    14.0       4       1.54                   2     500.0
# 131     17.3      16       2.80                   2    2304.0
# ...      ...     ...        ...                 ...       ...
# 578     14.0       8       1.94                   2    2048.0
# 996     15.6       6       2.20                   2     256.0
# 770     12.5      16       1.18                   2     256.0
# 407     15.6       4       2.20                   2    1024.0
# 418     14.0       8       1.70                   2     512.0
#
#       Screen_Resolution_Pixels  CPU_Frecuencia  Company_Group_Gama Alta  \
# 1118                   2073600             2.6                    False
# 153                    2073600             2.8                    False
# 275                    4096000             2.9                     True
# 1100                   2073600             2.3                    False
# 131                    2073600             1.8                    False
# ...                        ...             ...                      ...
# 578                    1049088             1.6                    False
# 996                    2073600             3.6                    False
# 770                    2073600             2.8                    False
# 407                    1049088             1.1                    False
# 418                    3686400             2.8                    False
#
#       Company_Group_Gama Baja  Company_Group_Gama Media  \
# 1118                    False                      True
# 153                     False                      True
# 275                     False                     False
# 1100                    False                      True
# 131                     False                      True
# ...                       ...                       ...
# 578                     False                      True
# 996                     False                      True
# 770                     False                      True
# 407                     False                      True
# 418                     False                      True
#
#       Company_Group_Gaming/Especializados  TypeName_Group_Alto rendimiento  \
# 1118                                False                             True
# 153                                 False                             True
# 275                                 False                            False
# 1100                                False                            False
# 131                                 False                            False
# ...                                   ...                              ...
# 578                                 False                            False
# 996                                 False                            False
# 770                                 False                            False
# 407                                 False                            False
# 418                                 False                            False
#
#       TypeName_Group_Bajo rendimiento  TypeName_Group_Intermedio  \
# 1118                            False                      False
# 153                             False                      False
# 275                             False                       True
# 1100                            False                       True
# 131                             False                       True
# ...                               ...                        ...
# 578                             False                       True
# 996                             False                       True
# 770                             False                       True
# 407                             False                       True
# 418                             False                       True
#
#       Disk_Types_Flash  Disk_Types_HDD  Disk_Types_Hybrid  Disk_Types_SSD  \
# 1118             False            True              False           False
# 153              False           False              False            True
# 275              False           False              False            True
# 1100             False            True              False           False
# 131              False           False               True           False
# ...                ...             ...                ...             ...
# 578              False            True              False           False
# 996              False           False              False            True
# 770              False           False              False            True
# 407              False            True              False           False
# 418              False           False              False            True
#
#       CPU_Marca_AMD  CPU_Marca_Intel
# 1118          False             True
# 153           False             True
# 275           False             True
# 1100          False             True
# 131           False             True
# ...             ...              ...
# 578           False             True
# 996            True            False
# 770           False             True
# 407           False             True
# 418           False             True
#
# [729 rows x 20 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 729 entries, 1118 to 418
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   inches                               729 non-null    float64
#  1   ram_gb                               729 non-null    int32
#  2   weight_kg                            729 non-null    float64
#  3   TypeName_Group_Num                   729 non-null    int64
#  4   Total_GB                             729 non-null    float64
#  5   Screen_Resolution_Pixels             729 non-null    int64
#  6   CPU_Frecuencia                       729 non-null    float64
#  7   Company_Group_Gama Alta              729 non-null    bool
#  8   Company_Group_Gama Baja              729 non-null    bool
#  9   Company_Group_Gama Media             729 non-null    bool
#  10  Company_Group_Gaming/Especializados  729 non-null    bool
#  11  TypeName_Group_Alto rendimiento      729 non-null    bool
#  12  TypeName_Group_Bajo rendimiento      729 non-null    bool
#  13  TypeName_Group_Intermedio            729 non-null    bool
#  14  Disk_Types_Flash                     729 non-null    bool
#  15  Disk_Types_HDD                       729 non-null    bool
#  16  Disk_Types_Hybrid                    729 non-null    bool
#  17  Disk_Types_SSD                       729 non-null    bool
#  18  CPU_Marca_AMD                        729 non-null    bool
#  19  CPU_Marca_Intel                      729 non-null    bool
# dtypes: bool(13), float64(4), int32(1), int64(2)
# memory usage: 52.0 KB

# %%
y_train
# Out:
# 1118    2899.00
# 153     1249.26
# 275     1958.90
# 1100    1030.99
# 131     1396.00
#          ...
# 578      389.00
# 996      549.00
# 770     1859.00
# 407      306.00
# 418     1943.00
# Name: Price_in_euros, Length: 729, dtype: float64

# %% [markdown]
# ### 3. Baseline de modelos

# %%
RFmodel=RandomForestRegressor()
RFmodel.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ### 4. Sacar métricas, valorar los modelos
#
# Recuerda que en la competición se va a evaluar con la métrica de ``RMSE``.

# %%
y_pred=RFmodel.predict(X_test)

# %%
RMSE= root_mean_squared_error(y_test, y_pred)
RMSE
# Out:
# 378.16656416228506

# %%
y_pred
# Out:
# array([1212.5645873 , 1157.37235   ,  874.61054333,  681.4205    ,
#         354.22159852,  308.263     ,  949.112     ,  304.1079    ,
#        1191.17042667, 1494.222     ,  436.27765   ,  906.7403    ,
#         750.11      , 1540.9048    ,  855.3398    , 1140.47393333,
#        1470.5648    ,  935.8142    , 4025.5269    , 1831.9615    ,
#         799.0745    , 1141.0664    , 1574.88821429, 1369.8548    ,
#         287.7169    , 1553.54865   ,  341.77913333,  514.7083    ,
#        1142.554     ,  692.17306667,  499.6294    ,  576.81085   ,
#        2735.4047    , 2054.4639    , 3309.12296667,  241.498     ,
#        1217.50096667,  465.92515   ,  511.964     ,  305.2159    ,
#        1044.36921667, 1567.0864    ,  512.22815   , 1431.6704    ,
#         547.20373333,  668.8599    ,  564.6538    ,  281.566     ,
#        1437.3664    , 3369.15106667, 3945.4304    , 1640.4158    ,
#        1076.5835    ,  689.9496    ,  774.9458    , 1788.2807    ,
#         436.87      , 1180.33686667, 1880.0704    , 2166.7658    ,
#         650.2652    ,  994.72517095, 1894.81086667,  651.01891   ,
#        1097.789     ,  684.63690167,  689.2449    ,  516.6984    ,
#         499.94423333, 1996.41126667, 2032.7189    , 1384.4286    ,
#        1289.0046    , 1875.35072222, 1609.93026667,  892.74      ,
#         307.82266667, 1967.06156667, 1545.0889    ,  245.1699    ,
#        1515.60583333,  856.423965  , 1924.8604    ,  311.02      ,
#         368.22069167,  512.22815   ,  577.7854    ,  483.066     ,
#         312.9298    ,  312.6318    , 2205.29      ,  578.2058    ,
#        2106.34      , 1758.43796667, 4225.071     ,  925.8532    ,
#         622.6153    , 2255.3495    , 1131.28503333, 1868.609     ,
#        1988.3017    ,  684.63690167,  605.982     , 2488.6913    ,
#         595.5884    , 2047.3286    ,  334.388     ,  957.052     ,
#         564.5941    , 1260.86103175,  677.184     ,  466.09711667,
#        2066.4814    ,  382.45143333, 1014.5868    , 1505.7095    ,
#        1438.54      ,  521.15543333,  828.244975  , 1557.39506667,
#        2327.8599    ,  586.389     , 1018.86193333,  627.308     ,
#        1461.5287    , 1064.547     ,  901.949175  , 1164.13156667,
#        2030.4869    ,  491.3697    ,  933.26349   , 1293.5664    ,
#        1111.8349    ,  636.4184    , 1704.55076667,  392.79248333,
#         422.9312    , 1574.8135    ,  460.8877    , 1521.5125    ,
#        1142.71652   , 1130.66144444, 1132.69452   , 1831.0089    ,
#        1619.26454286,  986.7814    ,  874.5725    ,  784.6799    ,
#        2067.1763    , 1958.53056667,  928.56966667, 1488.4591    ,
#        1053.02376667,  363.71815   ,  616.5092    ,  322.8797    ,
#         816.65798429,  719.5619    ,  391.8075    , 1676.10233333,
#        1624.0407    , 1258.8299    , 1596.4805    ,  926.06583333,
#        1222.65446667, 1235.0612    ,  465.92515   , 1555.22643333,
#         776.62395833,  574.8795    ,  606.93126667, 1100.65334762,
#         452.2582    , 1527.72500476,  318.46537354,  634.848     ,
#        1403.45145   , 1911.77666667,  997.8762    ,  311.02      ,
#         258.224     ,  986.6399    , 1186.2585    ])

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Una vez listo el modelo, toca predecir ``test.csv``

# %% [markdown]
# **RECUERDA: APLICAR LAS TRANSFORMACIONES QUE HAYAS REALIZADO EN `train.csv` a `test.csv`.**
#
#
# Véase:
# - Estandarización/Normalización
# - Eliminación de Outliers
# - Eliminación de columnas
# - Creación de columnas nuevas
# - Gestión de valores nulos
# - Y un largo etcétera de técnicas que como Data Scientist hayas considerado las mejores para tu dataset.

# %% [markdown]
# ### 1. Carga los datos de `test.csv` para predecir.

# %%
X_pred = pd.read_csv("data/test.csv", index_col=0)
X_pred.head()
# Out:
#           Company                          Product            TypeName  \
# laptop_ID
# 209        Lenovo               Legion Y520-15IKBN              Gaming
# 1281         Acer                   Aspire ES1-531            Notebook
# 1168       Lenovo  V110-15ISK (i3-6006U/4GB/1TB/No            Notebook
# 1231         Dell                    Inspiron 7579  2 in 1 Convertible
# 1020           HP                      ProBook 640            Notebook
#
#            Inches                           ScreenResolution  \
# laptop_ID
# 209          15.6                          Full HD 1920x1080
# 1281         15.6                                   1366x768
# 1168         15.6                                   1366x768
# 1231         15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 1020         14.0                          Full HD 1920x1080
#
#                                             Cpu   Ram     Memory  \
# laptop_ID
# 209                 Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD
# 1281       Intel Celeron Dual Core N3060 1.6GHz   4GB  500GB HDD
# 1168                 Intel Core i3 6006U 2.0GHz   4GB    1TB HDD
# 1231                 Intel Core i5 7200U 2.5GHz   8GB  256GB SSD
# 1020                 Intel Core i5 7200U 2.5GHz   4GB  256GB SSD
#
#                                Gpu       OpSys   Weight
# laptop_ID
# 209        Nvidia GeForce GTX 1060       No OS    2.4kg
# 1281         Intel HD Graphics 400       Linux    2.4kg
# 1168         Intel HD Graphics 520       No OS    1.9kg
# 1231         Intel HD Graphics 620  Windows 10  2.191kg
# 1020         Intel HD Graphics 620  Windows 10   1.95kg

# %%
X_pred.tail()
# Out:
#            Company          Product            TypeName  Inches  \
# laptop_ID
# 820            MSI      GE72MVR 7RG              Gaming    17.3
# 948        Toshiba  Tecra Z40-C-12X            Notebook    14.0
# 483           Dell  Precision M5520         Workstation    15.6
# 1017            HP      Probook 440            Notebook    14.0
# 421           Asus     ZenBook Flip  2 in 1 Convertible    13.3
#
#                                     ScreenResolution  \
# laptop_ID
# 820                                Full HD 1920x1080
# 948                      IPS Panel Full HD 1920x1080
# 483                                Full HD 1920x1080
# 1017                                        1366x768
# 421        IPS Panel Full HD / Touchscreen 1920x1080
#
#                                    Cpu   Ram                Memory  \
# laptop_ID
# 820        Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD +  1TB HDD
# 948         Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 483        Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 1017        Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 421         Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
#
#                                Gpu       OpSys  Weight
# laptop_ID
# 820        Nvidia GeForce GTX 1070  Windows 10   2.9kg
# 948          Intel HD Graphics 520  Windows 10  1.47kg
# 483            Nvidia Quadro M1200  Windows 10  1.78kg
# 1017         Intel HD Graphics 620  Windows 10  1.64kg
# 421          Intel HD Graphics 620  Windows 10  1.27kg

# %%
X_pred.index.name=None

# %%
X_pred["inches"]=X_pred.Inches.astype(float)
X_pred["ram_gb"]=X_pred['Ram'].str.replace('GB','').astype(int)
X_pred['weight_kg']=X_pred['Weight'].str.replace('kg','').astype(float)

# %%
# Crear un diccionario para las categorías de marcas
company_group_mapping = {
    'Apple': 'Gama Alta',
    'Microsoft': 'Gama Alta',
    'Razer': 'Gama Alta',
    'Google': 'Gama Alta',
    'LG': 'Gama Alta',
    'Dell': 'Gama Media',
    'Lenovo': 'Gama Media',
    'Asus': 'Gama Media',
    'HP': 'Gama Media',
    'Samsung': 'Gama Media',
    'Acer': 'Gama Baja',
    'Toshiba': 'Gama Baja',
    'Xiaomi': 'Gama Baja',
    'Chuwi': 'Gama Baja',
    'Mediacom': 'Gama Baja',
    'Fujitsu': 'Gama Baja',
    'MSI': 'Gaming/Especializados',
    'Huawei': 'Gama Alta',  # <- Nueva adición
    'Vero': 'Gama Baja'
}

# Aplicar el mapeo de las marcas a la nueva columna
X_pred['Company_Group'] = X_pred['Company'].map(company_group_mapping)

X_pred[['Company', 'Company_Group']].head()
# Out:
#      Company Company_Group
# 209   Lenovo    Gama Media
# 1281    Acer     Gama Baja
# 1168  Lenovo    Gama Media
# 1231    Dell    Gama Media
# 1020      HP    Gama Media

# %%
# Crear un diccionario para el mapeo de las nuevas categorías
type_name_mapping = {
    'Gaming': 'Alto rendimiento',
    'Workstation': 'Alto rendimiento',
    'Notebook': 'Intermedio',
    'Ultrabook': 'Intermedio',
    'Netbook': 'Bajo rendimiento',
    '2 in 1 Convertible': 'Bajo rendimiento'
}

# Reemplazar los valores de 'TypeName' con las nuevas categorías
X_pred['TypeName_Group'] = X_pred['TypeName'].map(type_name_mapping)

# Convertir las nuevas categorías en valores numéricos
type_name_group_numerical = {
    'Alto rendimiento': 3,
    'Intermedio': 2,
    'Bajo rendimiento': 1
}

# Aplicar el mapeo numérico
X_pred['TypeName_Group_Num'] = X_pred['TypeName_Group'].map(type_name_group_numerical)

# Ver el resultado
print(X_pred[['TypeName', 'TypeName_Group', 'TypeName_Group_Num']].head())
# Out:
#                 TypeName    TypeName_Group  TypeName_Group_Num
# 209               Gaming  Alto rendimiento                   3
# 1281            Notebook        Intermedio                   2
# 1168            Notebook        Intermedio                   2
# 1231  2 in 1 Convertible  Bajo rendimiento                   1
# 1020            Notebook        Intermedio                   2

# %%
import re

# Función para extraer el tamaño total en GB
def extract_total_gb(memory):
    # Inicializamos el tamaño total
    total_gb = 0
    
    # Separamos por "+" en caso de que haya varias combinaciones
    memory_items = memory.split('+')
    
    for item in memory_items:
        # Extraemos el tamaño (en GB o TB) y unidad
        match = re.match(r'(\d+\.?\d*)\s*(GB|TB)', item.strip())
        if match:
            size = float(match.group(1))  # Tamaño numérico
            unit = match.group(2)  # Unidad (GB o TB)
            
            # Si es TB, lo convertimos a GB
            if unit == 'TB':
                size *= 1024  # Convertir a GB
            total_gb += size  # Sumamos el tamaño total en GB
    
    return total_gb

# Aplicar las funciones a la columna 'Memory' para crear las nuevas columnas
X_pred['Total_GB'] = X_pred['Memory'].apply(extract_total_gb)
X_pred[['Memory', 'Total_GB']]
# Out:
#                     Memory  Total_GB
# 209              512GB SSD     512.0
# 1281             500GB HDD     500.0
# 1168               1TB HDD    1024.0
# 1231             256GB SSD     256.0
# 1020             256GB SSD     256.0
# ...                    ...       ...
# 820   512GB SSD +  1TB HDD    1536.0
# 948              128GB SSD     128.0
# 483              256GB SSD     256.0
# 1017             500GB HDD     500.0
# 421              256GB SSD     256.0
#
# [391 rows x 2 columns]

# %%
def extract_disk_types(memory):
    # Lista de posibles tipos de disco
    possible_types = ['SSD', 'HDD', 'Flash', 'Hybrid']
    
    # Extraemos los tipos presentes en la cadena
    disk_types = [disk for disk in possible_types if disk in memory]
    
    return ', '.join(disk_types)  
X_pred['Disk_Types'] = X_pred['Memory'].apply(extract_disk_types)
X_pred[['Memory', 'Total_GB', 'Disk_Types']]
# Out:
#                     Memory  Total_GB Disk_Types
# 209              512GB SSD     512.0        SSD
# 1281             500GB HDD     500.0        HDD
# 1168               1TB HDD    1024.0        HDD
# 1231             256GB SSD     256.0        SSD
# 1020             256GB SSD     256.0        SSD
# ...                    ...       ...        ...
# 820   512GB SSD +  1TB HDD    1536.0   SSD, HDD
# 948              128GB SSD     128.0        SSD
# 483              256GB SSD     256.0        SSD
# 1017             500GB HDD     500.0        HDD
# 421              256GB SSD     256.0        SSD
#
# [391 rows x 3 columns]

# %%
# Función para categorizar los tipos de disco
def categorize_disk_type(disk_type):
    single_types = {'SSD', 'HDD', 'Flash'}  # Tipos individuales permitidos
    disk_list = disk_type.split(', ')  # Convertir en lista
    
    # Si solo hay un tipo y está en los permitidos, mantenerlo
    if len(disk_list) == 1 and disk_list[0] in single_types:
        return disk_list[0]
    
    # Si hay más de un tipo, clasificarlo como 'Hybrid'
    return 'Hybrid'

# Aplicamos la función a la columna 'Disk_Types'
X_pred['Disk_Types'] = X_pred['Disk_Types'].apply(categorize_disk_type)

# Ver el resultado
print(X_pred[['Memory', 'Total_GB', 'Disk_Types']].head())
# Out:
#          Memory  Total_GB Disk_Types
# 209   512GB SSD     512.0        SSD
# 1281  500GB HDD     500.0        HDD
# 1168    1TB HDD    1024.0        HDD
# 1231  256GB SSD     256.0        SSD
# 1020  256GB SSD     256.0        SSD

# %%
print(X_pred['Disk_Types'].value_counts())
# Out:
# Disk_Types
# SSD       193
# HDD       119
# Hybrid     67
# Flash      12
# Name: count, dtype: int64

# %%
import re

# Función para extraer el número de píxeles de la resolución
def extract_pixels(screen_resolution):
    # Buscar el formato 'Ancho x Alto' (por ejemplo, 1920x1080)
    match = re.search(r'(\d+)x(\d+)', screen_resolution)
    
    if match:
        # Multiplicamos las dimensiones para obtener el total de píxeles
        width = int(match.group(1))
        height = int(match.group(2))
        return width * height  # Número total de píxeles
    return 0  # Si no se encuentra una resolución válida

# Función para extraer la categoría de la resolución (como 'Full HD', '4K', etc.)
def extract_resolution_type(screen_resolution):
    # Buscar la parte de la resolución que es la etiqueta (ej. 'Full HD', '4K', etc.)
    # El texto aparece antes de la resolución de píxeles
    match = re.search(r'([A-Za-z\s]+)(\d{4}x\d{3,4})', screen_resolution)
    
    if match:
        return match.group(1).strip()  # El nombre de la resolución, por ejemplo 'Full HD'
    return 'Unknown'  # Si no se puede extraer, ponemos 'Unknown'

# Aplicar las funciones a la columna 'ScreenResolution'
X_pred['Screen_Resolution_Pixels'] = X_pred['ScreenResolution'].apply(extract_pixels)
X_pred['Screen_Resolution_Type'] = X_pred['ScreenResolution'].apply(extract_resolution_type)

# Ver los resultados
X_pred[['ScreenResolution', 'Screen_Resolution_Pixels', 'Screen_Resolution_Type']].head()
# Out:
#                                ScreenResolution  Screen_Resolution_Pixels  \
# 209                           Full HD 1920x1080                   2073600
# 1281                                   1366x768                   1049088
# 1168                                   1366x768                   1049088
# 1231  IPS Panel Full HD / Touchscreen 1920x1080                   2073600
# 1020                          Full HD 1920x1080                   2073600
#
#      Screen_Resolution_Type
# 209                 Full HD
# 1281                Unknown
# 1168                Unknown
# 1231            Touchscreen
# 1020                Full HD

# %%
import pandas as pd
import re

# Función para separar la marca, modelo y frecuencia
def extract_cpu_info(cpu):
    # Identificar la marca
    if 'Intel' in cpu:
        marca = 'Intel'
    elif 'AMD' in cpu:
        marca = 'AMD'
    else:
        marca = 'Desconocido'

    # Extraer el modelo del procesador (esto incluiría el nombre de la serie y versión)
    modelo = re.sub(r'[0-9]+GHz|GHz|Core|M|Xeon|A[0-9]+|Pentium|Ryzen|Series', '', cpu).strip()

    # Extraer la frecuencia en GHz (si está presente)
    frecuencia = re.search(r'(\d+\.\d+|\d+)GHz', cpu)
    if frecuencia:
        # Quitar la unidad "GHz" y convertir a número flotante
        frecuencia = float(frecuencia.group(1))
    else:
        frecuencia = None  # Si no se encuentra la frecuencia, lo dejamos como None

    return marca, modelo, frecuencia

# Aplicamos la función a la columna Cpu
X_pred[['CPU_Marca', 'CPU_Modelo', 'CPU_Frecuencia']] = X_pred['Cpu'].apply(lambda x: pd.Series(extract_cpu_info(x)))

# Mostramos el DataFrame para ver el resultado
X_pred[['CPU_Marca', 'CPU_Modelo', 'CPU_Frecuencia']]
# Out:
#      CPU_Marca                    CPU_Modelo  CPU_Frecuencia
# 209      Intel           Intel  i7 7700HQ 2.             2.8
# 1281     Intel  Intel Celeron Dual  N3060 1.             1.6
# 1168     Intel            Intel  i3 6006U 2.             2.0
# 1231     Intel            Intel  i5 7200U 2.             2.5
# 1020     Intel            Intel  i5 7200U 2.             2.5
# ...        ...                           ...             ...
# 820      Intel           Intel  i7 7700HQ 2.             2.8
# 948      Intel            Intel  i5 6200U 2.             2.3
# 483      Intel           Intel  i7 7700HQ 2.             2.8
# 1017     Intel            Intel  i5 7200U 2.             2.5
# 421      Intel            Intel  i5 7200U 2.             2.5
#
# [391 rows x 3 columns]

# %%
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391 entries, 209 to 421
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company                   391 non-null    object
#  1   Product                   391 non-null    object
#  2   TypeName                  391 non-null    object
#  3   Inches                    391 non-null    float64
#  4   ScreenResolution          391 non-null    object
#  5   Cpu                       391 non-null    object
#  6   Ram                       391 non-null    object
#  7   Memory                    391 non-null    object
#  8   Gpu                       391 non-null    object
#  9   OpSys                     391 non-null    object
#  10  Weight                    391 non-null    object
#  11  inches                    391 non-null    float64
#  12  ram_gb                    391 non-null    int32
#  13  weight_kg                 391 non-null    float64
#  14  Company_Group             391 non-null    object
#  15  TypeName_Group            391 non-null    object
#  16  TypeName_Group_Num        391 non-null    int64
#  17  Total_GB                  391 non-null    float64
#  18  Disk_Types                391 non-null    object
#  19  Screen_Resolution_Pixels  391 non-null    int64
#  20  Screen_Resolution_Type    391 non-null    object
#  21  CPU_Marca                 391 non-null    object
#  22  CPU_Modelo                391 non-null    object
#  23  CPU_Frecuencia            391 non-null    float64
# dtypes: float64(5), int32(1), int64(2), object(16)
# memory usage: 74.8+ KB

# %%
X_pred =X_pred.iloc[:,11:].copy()

# %%
X_pred=X_pred.drop(columns=['CPU_Modelo', 'Screen_Resolution_Type'])

# %%
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391 entries, 209 to 421
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   inches                    391 non-null    float64
#  1   ram_gb                    391 non-null    int32
#  2   weight_kg                 391 non-null    float64
#  3   Company_Group             391 non-null    object
#  4   TypeName_Group            391 non-null    object
#  5   TypeName_Group_Num        391 non-null    int64
#  6   Total_GB                  391 non-null    float64
#  7   Disk_Types                391 non-null    object
#  8   Screen_Resolution_Pixels  391 non-null    int64
#  9   CPU_Marca                 391 non-null    object
#  10  CPU_Frecuencia            391 non-null    float64
# dtypes: float64(4), int32(1), int64(2), object(4)
# memory usage: 35.1+ KB

# %%
X_pred= pd.get_dummies(X_pred, columns=['Company_Group', 'TypeName_Group', 'Disk_Types', 'CPU_Marca'])

# %%
X_pred.columns
# Out:
# Index(['inches', 'ram_gb', 'weight_kg', 'TypeName_Group_Num', 'Total_GB',
#        'Screen_Resolution_Pixels', 'CPU_Frecuencia', 'Company_Group_Gama Alta',
#        'Company_Group_Gama Baja', 'Company_Group_Gama Media',
#        'Company_Group_Gaming/Especializados',
#        'TypeName_Group_Alto rendimiento', 'TypeName_Group_Bajo rendimiento',
#        'TypeName_Group_Intermedio', 'Disk_Types_Flash', 'Disk_Types_HDD',
#        'Disk_Types_Hybrid', 'Disk_Types_SSD', 'CPU_Marca_AMD',
#        'CPU_Marca_Desconocido', 'CPU_Marca_Intel'],
#       dtype='object')

# %%
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391 entries, 209 to 421
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   inches                               391 non-null    float64
#  1   ram_gb                               391 non-null    int32
#  2   weight_kg                            391 non-null    float64
#  3   TypeName_Group_Num                   391 non-null    int64
#  4   Total_GB                             391 non-null    float64
#  5   Screen_Resolution_Pixels             391 non-null    int64
#  6   CPU_Frecuencia                       391 non-null    float64
#  7   Company_Group_Gama Alta              391 non-null    bool
#  8   Company_Group_Gama Baja              391 non-null    bool
#  9   Company_Group_Gama Media             391 non-null    bool
#  10  Company_Group_Gaming/Especializados  391 non-null    bool
#  11  TypeName_Group_Alto rendimiento      391 non-null    bool
#  12  TypeName_Group_Bajo rendimiento      391 non-null    bool
#  13  TypeName_Group_Intermedio            391 non-null    bool
#  14  Disk_Types_Flash                     391 non-null    bool
#  15  Disk_Types_HDD                       391 non-null    bool
#  16  Disk_Types_Hybrid                    391 non-null    bool
#  17  Disk_Types_SSD                       391 non-null    bool
#  18  CPU_Marca_AMD                        391 non-null    bool
#  19  CPU_Marca_Desconocido                391 non-null    bool
#  20  CPU_Marca_Intel                      391 non-null    bool
# dtypes: bool(14), float64(4), int32(1), int64(2)
# memory usage: 28.3 KB

# %%
X_pred=X_pred.drop(columns=['CPU_Marca_Desconocido'])

# %%
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391 entries, 209 to 421
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   inches                               391 non-null    float64
#  1   ram_gb                               391 non-null    int32
#  2   weight_kg                            391 non-null    float64
#  3   TypeName_Group_Num                   391 non-null    int64
#  4   Total_GB                             391 non-null    float64
#  5   Screen_Resolution_Pixels             391 non-null    int64
#  6   CPU_Frecuencia                       391 non-null    float64
#  7   Company_Group_Gama Alta              391 non-null    bool
#  8   Company_Group_Gama Baja              391 non-null    bool
#  9   Company_Group_Gama Media             391 non-null    bool
#  10  Company_Group_Gaming/Especializados  391 non-null    bool
#  11  TypeName_Group_Alto rendimiento      391 non-null    bool
#  12  TypeName_Group_Bajo rendimiento      391 non-null    bool
#  13  TypeName_Group_Intermedio            391 non-null    bool
#  14  Disk_Types_Flash                     391 non-null    bool
#  15  Disk_Types_HDD                       391 non-null    bool
#  16  Disk_Types_Hybrid                    391 non-null    bool
#  17  Disk_Types_SSD                       391 non-null    bool
#  18  CPU_Marca_AMD                        391 non-null    bool
#  19  CPU_Marca_Intel                      391 non-null    bool
# dtypes: bool(13), float64(4), int32(1), int64(2)
# memory usage: 27.9 KB

# %% [markdown]
#  ## 2. Replicar el procesado para ``test.csv``

# %%
X_pred
# Out:
#       inches  ram_gb  weight_kg  TypeName_Group_Num  Total_GB  \
# 209     15.6      16      2.400                   3     512.0
# 1281    15.6       4      2.400                   2     500.0
# 1168    15.6       4      1.900                   2    1024.0
# 1231    15.6       8      2.191                   1     256.0
# 1020    14.0       4      1.950                   2     256.0
# ...      ...     ...        ...                 ...       ...
# 820     17.3      16      2.900                   3    1536.0
# 948     14.0       4      1.470                   2     128.0
# 483     15.6       8      1.780                   3     256.0
# 1017    14.0       4      1.640                   2     500.0
# 421     13.3       8      1.270                   1     256.0
#
#       Screen_Resolution_Pixels  CPU_Frecuencia  Company_Group_Gama Alta  \
# 209                    2073600             2.8                    False
# 1281                   1049088             1.6                    False
# 1168                   1049088             2.0                    False
# 1231                   2073600             2.5                    False
# 1020                   2073600             2.5                    False
# ...                        ...             ...                      ...
# 820                    2073600             2.8                    False
# 948                    2073600             2.3                    False
# 483                    2073600             2.8                    False
# 1017                   1049088             2.5                    False
# 421                    2073600             2.5                    False
#
#       Company_Group_Gama Baja  Company_Group_Gama Media  \
# 209                     False                      True
# 1281                     True                     False
# 1168                    False                      True
# 1231                    False                      True
# 1020                    False                      True
# ...                       ...                       ...
# 820                     False                     False
# 948                      True                     False
# 483                     False                      True
# 1017                    False                      True
# 421                     False                      True
#
#       Company_Group_Gaming/Especializados  TypeName_Group_Alto rendimiento  \
# 209                                 False                             True
# 1281                                False                            False
# 1168                                False                            False
# 1231                                False                            False
# 1020                                False                            False
# ...                                   ...                              ...
# 820                                  True                             True
# 948                                 False                            False
# 483                                 False                             True
# 1017                                False                            False
# 421                                 False                            False
#
#       TypeName_Group_Bajo rendimiento  TypeName_Group_Intermedio  \
# 209                             False                      False
# 1281                            False                       True
# 1168                            False                       True
# 1231                             True                      False
# 1020                            False                       True
# ...                               ...                        ...
# 820                             False                      False
# 948                             False                       True
# 483                             False                      False
# 1017                            False                       True
# 421                              True                      False
#
#       Disk_Types_Flash  Disk_Types_HDD  Disk_Types_Hybrid  Disk_Types_SSD  \
# 209              False           False              False            True
# 1281             False            True              False           False
# 1168             False            True              False           False
# 1231             False           False              False            True
# 1020             False           False              False            True
# ...                ...             ...                ...             ...
# 820              False           False               True           False
# 948              False           False              False            True
# 483              False           False              False            True
# 1017             False            True              False           False
# 421              False           False              False            True
#
#       CPU_Marca_AMD  CPU_Marca_Intel
# 209           False             True
# 1281          False             True
# 1168          False             True
# 1231          False             True
# 1020          False             True
# ...             ...              ...
# 820           False             True
# 948           False             True
# 483           False             True
# 1017          False             True
# 421           False             True
#
# [391 rows x 20 columns]

# %%
predictions_submit = RFmodel.predict(X_pred)
predictions_submit
# Out:
# array([1411.89016667,  297.86552583,  378.29723333, 1017.71574167,
#         870.0398    ,  498.29616667,  859.94981667, 1203.16593333,
#        1607.6475    ,  289.20266667, 2527.31727   , 1482.885     ,
#         558.83545   , 1589.13303333,  799.0013    ,  592.53286   ,
#        1451.4562    , 1428.051     , 1622.1844    ,  636.4184    ,
#        1329.97196667,  273.487     ,  613.9836    , 1599.85316667,
#         484.6597    ,  651.01891   ,  527.951     ,  408.8598    ,
#        2327.83629333,  987.3814    , 1978.8181019 ,  343.27813333,
#         715.5895    , 3056.2101    , 2498.121     , 1976.08985317,
#         627.308     , 1321.42104286,  957.185     , 1505.2246    ,
#         496.3549    ,  917.1812    ,  564.5941    , 1105.3324    ,
#        1182.69593333, 1151.164     ,  999.43928333,  574.2642    ,
#         801.64994167,  441.985     , 1985.8865    ,  700.88406   ,
#        1199.1805619 ,  703.51253667, 1741.8183    , 1757.22      ,
#         624.9984    ,  905.89557143,  913.4355    ,  542.4597    ,
#        3086.76      , 2024.7087    ,  456.84994762, 1961.34      ,
#        1222.65446667, 1123.899725  ,  894.9714    , 1450.3921    ,
#        1778.997     , 2243.01      ,  771.01260833,  436.878     ,
#        1054.6508    , 1826.6603    , 1049.30081667, 1305.3446    ,
#        1379.22017   , 1678.27423333, 1490.4325    , 1385.8625    ,
#         758.50463333, 1325.41071333, 2228.8011    , 1381.5941    ,
#        1441.412     , 1669.8129    ,  662.17      ,  862.72816667,
#         742.7057    ,  934.589775  ,  537.5795    , 2017.2741    ,
#        1080.6373    , 3679.2095    , 3371.07146667, 1227.47326667,
#         823.1947    ,  518.02458333, 1102.613255  , 1020.8054    ,
#        1549.8649127 ,  713.3086    , 1362.584     , 1038.69163333,
#         409.640035  , 1771.18856667, 1695.9833    ,  623.332     ,
#         365.91752167, 1079.0198    , 1543.55466667,  734.1352    ,
#         777.039     ,  801.64994167, 1155.43128571,  574.4359    ,
#         536.7547    , 1594.79941   , 1876.42516667, 1146.92506667,
#        1037.43297119,  729.8394    , 1120.13      , 1598.09466667,
#        1078.16546667,  591.325945  , 1562.53706667, 1040.50306667,
#         550.3009    ,  917.69865   , 1237.425     , 1372.11      ,
#        1766.45407143, 1907.2335    ,  808.49053667, 2413.69285714,
#        1221.1605873 , 1320.8937    , 1711.76      ,  570.5897    ,
#        1373.41093333,  799.0745    , 1296.176     , 1095.9855    ,
#        1584.63      , 1146.92506667,  929.79686667,  843.0668    ,
#        1502.27577143,  830.6271    ,  772.099     ,  828.4636    ,
#         542.5669    , 1365.5895    ,  856.24366667,  857.11676667,
#        1280.0902    , 1018.1581    ,  849.59107333,  329.92605357,
#         372.6769    , 2132.2716    , 1180.6665    ,  666.1511    ,
#         930.7438    ,  988.50665   , 1996.51130952,  215.196     ,
#         880.6849    ,  896.8038    , 1236.73245667,  400.3844    ,
#         409.640035  ,  790.5388    , 2401.85463333,  598.2505    ,
#        1174.3956    ,  543.2791    , 1029.8779    , 1115.029     ,
#         499.94423333, 5425.4394    ,  999.92723333, 1026.3916    ,
#        1378.86206667, 2083.6217    ,  568.7615    ,  834.9899    ,
#        1443.35      ,  791.94905556,  644.8791    , 2003.7422    ,
#         666.2665    ,  643.2617    ,  671.3475    ,  339.2378    ,
#         929.79686667,  992.04255   ,  684.63690167,  298.2381    ,
#        1120.13      , 2121.2928    , 1256.7354    ,  663.05      ,
#         682.2893    ,  386.80026667, 2132.3137    ,  329.92605357,
#        1740.05583333,  428.648     , 1323.00876667,  882.2243    ,
#         854.6632    , 1117.6405    ,  618.5779    , 1464.0784    ,
#        1210.91833762,  681.921     ,  673.5476    ,  578.2058    ,
#         462.48350595, 1382.08506667, 1191.17042667, 1453.0445    ,
#        1025.7354    , 1079.0198    ,  408.1378    , 1196.98783429,
#         666.9556    , 1779.19583333,  460.8877    ,  465.92515   ,
#         912.4725    , 1080.4842    ,  273.94556667,  843.0668    ,
#        3133.15245   , 1039.85436667,  980.446075  , 1093.55383333,
#        1853.63      ,  627.308     , 1164.7361    , 1357.5492    ,
#        1074.296     , 2532.07063333, 1086.07      ,  789.829745  ,
#         880.03325556, 2035.0305    , 1410.25574357,  463.54225   ,
#        1996.41126667,  893.83565   , 1996.41126667, 2572.58208   ,
#         510.5343    ,  455.3956    , 1138.0801    , 1064.7122    ,
#         388.777     ,  633.81653333, 1384.4286    ,  473.35758333,
#        2421.04341   , 1772.0234    , 1309.54      ,  404.6946    ,
#        2033.514     , 1665.6189    ,  740.9833    ,  556.8395    ,
#        1083.65603333,  993.38855   , 1301.2755    ,  941.387     ,
#         460.14550595,  850.9356    ,  976.13303333,  421.7377    ,
#         596.45065333, 1012.5132    , 1420.06696667,  602.70023333,
#         413.85025   , 1043.01398238, 1078.6402    , 1630.71841905,
#        3285.86006667,  511.964     , 1050.5150619 , 1348.62743333,
#        1479.7759    , 1284.1078    , 1158.21098929, 1417.9154    ,
#        1389.0301    ,  779.3824    , 4246.2594    , 1019.719     ,
#        1705.22116667,  557.21658667,  298.259     ,  458.95495   ,
#         825.6318    , 1448.4111    , 1671.7249    ,  734.5372    ,
#        1982.4656    , 1370.7921    ,  527.2354    ,  962.44925   ,
#         459.6154    ,  484.6597    ,  816.65798429, 1180.33686667,
#        2625.89852333, 1175.16133333,  992.11635   ,  787.0974    ,
#        1538.7955    , 1142.52565   , 1210.07485333,  778.81901389,
#        1280.26      , 2192.3078    , 2006.9768    ,  622.5449    ,
#         512.22815   , 2044.281     ,  404.55478333,  988.95475   ,
#        1636.9162    ,  857.4945    ,  503.008     , 1020.8054    ,
#         428.648     ,  511.964     , 1378.6011    , 1174.89      ,
#         473.30203333,  463.54225   , 1294.88646667, 1508.62383333,
#        1853.63      ,  776.62395833,  354.22159852, 1365.9742    ,
#         688.5296    ,  578.4738    , 1016.06366667, 1095.435     ,
#         496.19      ,  417.1461    ,  618.388     ,  313.40978571,
#        1730.44946667,  815.9147    , 1050.4792    , 1846.6048    ,
#         512.22815   ,  699.004     ,  687.0691    ,  940.032     ,
#        1209.728     , 1448.544     , 1674.0187    , 3669.5872    ,
#         925.515525  , 1932.1295    , 1985.6907    , 1293.6212    ,
#         642.6012    , 1491.00066667, 1164.24392833, 1918.5512    ,
#         596.45065333,  963.9416    ,  710.42056667,  742.9884    ,
#         416.8998    , 1095.435     , 1362.26436667,  417.54516667,
#        1803.585     , 1060.64185   , 2087.64499524,  998.655     ,
#        1580.22725667,  954.645625  , 1511.3646    ])

# %% [markdown]
# **¡OJO! ¿Por qué me da error?**

# %% [markdown]
# IMPORTANTE:
#
# - SI EL ARRAY CON EL QUE HICISTEIS `.fit()` ERA DE 4 COLUMNAS, PARA `.predict()` DEBEN SER LAS MISMAS
# - SI AL ARRAY CON EL QUE HICISTEIS `.fit()` LO NORMALIZASTEIS, PARA `.predict()` DEBÉIS NORMALIZARLO
# - TODO IGUAL SALVO **BORRAR FILAS**, EL NÚMERO DE ROWS SE DEBE MANTENER EN ESTE SET, PUES LA PREDICCIÓN DEBE TENER **391 FILAS**, SI O SI

# %% [markdown]
# **Entonces, si al cargar los datos de ``train.csv`` usaste `index_col=0`, ¿tendré que hacer lo también para el `test.csv`?**

# %%
# ¿Qué opináis?
# ¿Sí, no?

# %% [markdown]
# ![wow.jpeg](attachment:wow.jpeg)

# %% [markdown]
# ### 3. **¿Qué es lo que subirás a Kaggle?**

# %% [markdown]
# **Para subir a Kaggle la predicción esta tendrá que tener una forma específica.**
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
sample = pd.read_csv("./data/sample_submission.csv")

# %%
sample.head()
# Out:
#    laptop_ID  Price_in_euros
# 0        209          1949.1
# 1       1281           805.0
# 2       1168          1101.0
# 3       1231          1293.8
# 4       1020          1832.6

# %%
sample.shape
# Out:
# (391, 2)

# %% [markdown]
# ### 4. Mete tus predicciones en un dataframe llamado ``submission``.

# %%
#¿Cómo creamos la submission?
submission = pd.DataFrame({'laptop_ID':X_pred.index,'Price_in_euros':predictions_submit})

# %%
submission.head()
# Out:
#    laptop_ID  Price_in_euros
# 0        209     1411.890167
# 1       1281      297.865526
# 2       1168      378.297233
# 3       1231     1017.715742
# 4       1020      870.039800

# %%
submission.shape
# Out:
# (391, 2)

# %% [markdown]
# ### 5. Pásale el CHEQUEADOR para comprobar que efectivamente está listo para subir a Kaggle.

# %%
def chequeador(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.laptop_ID.all() == sample.laptop_ID.all():
                print("You're ready to submit!")
                submission.to_csv("submissionentrega.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://www.mihaileric.com/static/evaluation-meme-e0a350f278a36346e6d46b139b1d0da0-ed51e.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto del TA: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `test.csv`. Lloro.")

# %%
chequeador(submission)
# Out:
# You're ready to submit!
